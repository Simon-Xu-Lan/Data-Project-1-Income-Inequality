# %%
# import dependecies 
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress
import csv

# %% [markdown]
# ## Evaluate Data from 2009-2019
# - Gini coefficient (proportion of income / total population)
# - Summarize the GDP (CPI) / per capita of the countries OECD

# %%
# read csv
file_path=os.path.join('Income_Distribution_OECD_013021.csv')
df=pd.read_csv(file_path)
#df.head()
# Out:
# /Users/triciaharris/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#df.count()

# %%
# clean dataframe so years < 2009 are removed

# %%
cleaned_years_df = df.query('Year > 2008')
cleaned_years_df
# Out:
#       LOCATION    Country   MEASURE  \
# 0          AUS  Australia      GINI
# 1          AUS  Australia      GINI
# 2          AUS  Australia      GINI
# 3          AUS  Australia      GINI
# 6          AUS  Australia      GINI
# 7          AUS  Australia      GINI
# 8          AUS  Australia   CPI2010
# 9          AUS  Australia   CPI2010
# 10         AUS  Australia   CPI2010
# 11         AUS  Australia   CPI2010
# 14         AUS  Australia   CPI2010
# 15         AUS  Australia   CPI2010
# 16         AUS  Australia    PVTAA1
# 17         AUS  Australia    PVTAA1
# 18         AUS  Australia    PVTAA1
# 19         AUS  Australia    PVTAA1
# 22         AUS  Australia    PVTAA1
# 23         AUS  Australia    PVTAA1
# 24         AUS  Australia   ECTOTAL
# 25         AUS  Australia   ECTOTAL
# 26         AUS  Australia   ECTOTAL
# 27         AUS  Australia   ECTOTAL
# 30         AUS  Australia   ECTOTAL
# 31         AUS  Australia   ECTOTAL
# 34         AUS  Australia  SECTOTAL
# 35         AUS  Australia  SECTOTAL
# 36         AUS  Australia  TACTOTAL
# 37         AUS  Australia  TACTOTAL
# 38         AUS  Australia  TACTOTAL
# 39         AUS  Australia  TACTOTAL
# ...        ...        ...       ...
# 66093      ROU    Romania   PMEAN5A
# 66094      ROU    Romania   PMEAN5A
# 66095      ROU    Romania   PMEAN5A
# 66096      ROU    Romania   PMEAN5A
# 66097      ROU    Romania   PMEAN5A
# 66098      ROU    Romania   PMEAN5A
# 66099      ROU    Romania   PMEAN5A
# 66100      ROU    Romania   PMEAN5A
# 66104      ROU    Romania   CPI2015
# 66105      ROU    Romania   CPI2015
# 66106      ROU    Romania   CPI2015
# 66107      ROU    Romania   CPI2015
# 66108      ROU    Romania   CPI2015
# 66109      ROU    Romania   CPI2015
# 66110      ROU    Romania   CPI2015
# 66111      ROU    Romania   CPI2015
# 66112      ROU    Romania   CPI2015
# 66113      ROU    Romania   CPI2015
# 66117      BGR   Bulgaria     GINIB
# 66118      BGR   Bulgaria     GINIB
# 66119      BGR   Bulgaria     GINIB
# 66120      BGR   Bulgaria     GINIB
# 66121      BGR   Bulgaria     GINIB
# 66122      BGR   Bulgaria     GINIB
# 66123      BGR   Bulgaria     GINIB
# 66124      BGR   Bulgaria     GINIB
# 66125      BGR   Bulgaria     GINIB
# 66126      BGR   Bulgaria     GINIB
# 66127      SWE     Sweden       HHD
# 66128      SWE     Sweden       HHD
#
#                                                  Measure  AGE  \
# 0      Gini (disposable income, post taxes and transf...  TOT
# 1      Gini (disposable income, post taxes and transf...  TOT
# 2      Gini (disposable income, post taxes and transf...  TOT
# 3      Gini (disposable income, post taxes and transf...  TOT
# 6      Gini (disposable income, post taxes and transf...  TOT
# 7      Gini (disposable income, post taxes and transf...  TOT
# 8                   Consumer Price Index (base 2010=100)  TOT
# 9                   Consumer Price Index (base 2010=100)  TOT
# 10                  Consumer Price Index (base 2010=100)  TOT
# 11                  Consumer Price Index (base 2010=100)  TOT
# 14                  Consumer Price Index (base 2010=100)  TOT
# 15                  Consumer Price Index (base 2010=100)  TOT
# 16     Age group 0-17: Poverty rate after taxes and t...  TOT
# 17     Age group 0-17: Poverty rate after taxes and t...  TOT
# 18     Age group 0-17: Poverty rate after taxes and t...  TOT
# 19     Age group 0-17: Poverty rate after taxes and t...  TOT
# 22     Age group 0-17: Poverty rate after taxes and t...  TOT
# 23     Age group 0-17: Poverty rate after taxes and t...  TOT
# 24                       Total earnings (current prices)  TOT
# 25                       Total earnings (current prices)  TOT
# 26                       Total earnings (current prices)  TOT
# 27                       Total earnings (current prices)  TOT
# 30                       Total earnings (current prices)  TOT
# 31                       Total earnings (current prices)  TOT
# 34          Income from self-employment (current prices)  TOT
# 35          Income from self-employment (current prices)  TOT
# 36     Taxes and social security contributions paid d...  TOT
# 37     Taxes and social security contributions paid d...  TOT
# 38     Taxes and social security contributions paid d...  TOT
# 39     Taxes and social security contributions paid d...  TOT
# ...                                                  ...  ...
# 66093  Mean Poverty gap after taxes and transfers, Po...  OLD
# 66094  Mean Poverty gap after taxes and transfers, Po...  OLD
# 66095  Mean Poverty gap after taxes and transfers, Po...  OLD
# 66096  Mean Poverty gap after taxes and transfers, Po...  OLD
# 66097  Mean Poverty gap after taxes and transfers, Po...  OLD
# 66098  Mean Poverty gap after taxes and transfers, Po...  OLD
# 66099  Mean Poverty gap after taxes and transfers, Po...  OLD
# 66100  Mean Poverty gap after taxes and transfers, Po...  OLD
# 66104               Consumer Price Index (base 2015=100)  TOT
# 66105               Consumer Price Index (base 2015=100)  TOT
# 66106               Consumer Price Index (base 2015=100)  TOT
# 66107               Consumer Price Index (base 2015=100)  TOT
# 66108               Consumer Price Index (base 2015=100)  TOT
# 66109               Consumer Price Index (base 2015=100)  TOT
# 66110               Consumer Price Index (base 2015=100)  TOT
# 66111               Consumer Price Index (base 2015=100)  TOT
# 66112               Consumer Price Index (base 2015=100)  TOT
# 66113               Consumer Price Index (base 2015=100)  TOT
# 66117   Gini (market income, before taxes and transfers)  OLD
# 66118   Gini (market income, before taxes and transfers)  OLD
# 66119   Gini (market income, before taxes and transfers)  OLD
# 66120   Gini (market income, before taxes and transfers)  OLD
# 66121   Gini (market income, before taxes and transfers)  OLD
# 66122   Gini (market income, before taxes and transfers)  OLD
# 66123   Gini (market income, before taxes and transfers)  OLD
# 66124   Gini (market income, before taxes and transfers)  OLD
# 66125   Gini (market income, before taxes and transfers)  OLD
# 66126   Gini (market income, before taxes and transfers)  OLD
# 66127                         Total number of households  OLD
# 66128                         Total number of households   WA
#
#                                  Age group DEFINITION          Definition  \
# 0                         Total population    CURRENT  Current definition
# 1                         Total population    CURRENT  Current definition
# 2                         Total population    CURRENT  Current definition
# 3                         Total population    CURRENT  Current definition
# 6                         Total population    CURRENT  Current definition
# 7                         Total population    CURRENT  Current definition
# 8                         Total population    CURRENT  Current definition
# 9                         Total population    CURRENT  Current definition
# 10                        Total population    CURRENT  Current definition
# 11                        Total population    CURRENT  Current definition
# 14                        Total population    CURRENT  Current definition
# 15                        Total population    CURRENT  Current definition
# 16                        Total population    CURRENT  Current definition
# 17                        Total population    CURRENT  Current definition
# 18                        Total population    CURRENT  Current definition
# 19                        Total population    CURRENT  Current definition
# 22                        Total population    CURRENT  Current definition
# 23                        Total population    CURRENT  Current definition
# 24                        Total population    CURRENT  Current definition
# 25                        Total population    CURRENT  Current definition
# 26                        Total population    CURRENT  Current definition
# 27                        Total population    CURRENT  Current definition
# 30                        Total population    CURRENT  Current definition
# 31                        Total population    CURRENT  Current definition
# 34                        Total population    CURRENT  Current definition
# 35                        Total population    CURRENT  Current definition
# 36                        Total population    CURRENT  Current definition
# 37                        Total population    CURRENT  Current definition
# 38                        Total population    CURRENT  Current definition
# 39                        Total population    CURRENT  Current definition
# ...                                    ...        ...                 ...
# 66093  Retirement age population: above 65    CURRENT  Current definition
# 66094  Retirement age population: above 65    CURRENT  Current definition
# 66095  Retirement age population: above 65    CURRENT  Current definition
# 66096  Retirement age population: above 65    CURRENT  Current definition
# 66097  Retirement age population: above 65    CURRENT  Current definition
# 66098  Retirement age population: above 65    CURRENT  Current definition
# 66099  Retirement age population: above 65    CURRENT  Current definition
# 66100  Retirement age population: above 65    CURRENT  Current definition
# 66104                     Total population    CURRENT  Current definition
# 66105                     Total population    CURRENT  Current definition
# 66106                     Total population    CURRENT  Current definition
# 66107                     Total population    CURRENT  Current definition
# 66108                     Total population    CURRENT  Current definition
# 66109                     Total population    CURRENT  Current definition
# 66110                     Total population    CURRENT  Current definition
# 66111                     Total population    CURRENT  Current definition
# 66112                     Total population    CURRENT  Current definition
# 66113                     Total population    CURRENT  Current definition
# 66117  Retirement age population: above 65    CURRENT  Current definition
# 66118  Retirement age population: above 65    CURRENT  Current definition
# 66119  Retirement age population: above 65    CURRENT  Current definition
# 66120  Retirement age population: above 65    CURRENT  Current definition
# 66121  Retirement age population: above 65    CURRENT  Current definition
# 66122  Retirement age population: above 65    CURRENT  Current definition
# 66123  Retirement age population: above 65    CURRENT  Current definition
# 66124  Retirement age population: above 65    CURRENT  Current definition
# 66125  Retirement age population: above 65    CURRENT  Current definition
# 66126  Retirement age population: above 65    CURRENT  Current definition
# 66127  Retirement age population: above 65    CURRENT  Current definition
# 66128        Working age population: 18-65    CURRENT  Current definition
#
#         METHODO                       Methodology  ...   Year  Unit Code  \
# 0      METH2012  New income definition since 2012  ...   2012     0_TO_1
# 1      METH2012  New income definition since 2012  ...   2014     0_TO_1
# 2      METH2012  New income definition since 2012  ...   2016     0_TO_1
# 3      METH2012  New income definition since 2012  ...   2018     0_TO_1
# 6      METH2011      Income definition until 2011  ...   2010     0_TO_1
# 7      METH2011      Income definition until 2011  ...   2012     0_TO_1
# 8      METH2012  New income definition since 2012  ...   2012        IDX
# 9      METH2012  New income definition since 2012  ...   2014        IDX
# 10     METH2012  New income definition since 2012  ...   2016        IDX
# 11     METH2012  New income definition since 2012  ...   2018        IDX
# 14     METH2011      Income definition until 2011  ...   2010        IDX
# 15     METH2011      Income definition until 2011  ...   2012        IDX
# 16     METH2012  New income definition since 2012  ...   2012      RATIO
# 17     METH2012  New income definition since 2012  ...   2014      RATIO
# 18     METH2012  New income definition since 2012  ...   2016      RATIO
# 19     METH2012  New income definition since 2012  ...   2018      RATIO
# 22     METH2011      Income definition until 2011  ...   2010      RATIO
# 23     METH2011      Income definition until 2011  ...   2012      RATIO
# 24     METH2012  New income definition since 2012  ...   2012        AUD
# 25     METH2012  New income definition since 2012  ...   2014        AUD
# 26     METH2012  New income definition since 2012  ...   2016        AUD
# 27     METH2012  New income definition since 2012  ...   2018        AUD
# 30     METH2011      Income definition until 2011  ...   2010        AUD
# 31     METH2011      Income definition until 2011  ...   2012        AUD
# 34     METH2011      Income definition until 2011  ...   2010        AUD
# 35     METH2011      Income definition until 2011  ...   2012        AUD
# 36     METH2012  New income definition since 2012  ...   2012        AUD
# 37     METH2012  New income definition since 2012  ...   2014        AUD
# 38     METH2012  New income definition since 2012  ...   2016        AUD
# 39     METH2012  New income definition since 2012  ...   2018        AUD
# ...         ...                               ...  ...    ...        ...
# 66093  METH2012  New income definition since 2012  ...   2011      RATIO
# 66094  METH2012  New income definition since 2012  ...   2012      RATIO
# 66095  METH2012  New income definition since 2012  ...   2013      RATIO
# 66096  METH2012  New income definition since 2012  ...   2014      RATIO
# 66097  METH2012  New income definition since 2012  ...   2015      RATIO
# 66098  METH2012  New income definition since 2012  ...   2016      RATIO
# 66099  METH2012  New income definition since 2012  ...   2017      RATIO
# 66100  METH2012  New income definition since 2012  ...   2018      RATIO
# 66104  METH2012  New income definition since 2012  ...   2009        IDX
# 66105  METH2012  New income definition since 2012  ...   2010        IDX
# 66106  METH2012  New income definition since 2012  ...   2011        IDX
# 66107  METH2012  New income definition since 2012  ...   2012        IDX
# 66108  METH2012  New income definition since 2012  ...   2013        IDX
# 66109  METH2012  New income definition since 2012  ...   2014        IDX
# 66110  METH2012  New income definition since 2012  ...   2015        IDX
# 66111  METH2012  New income definition since 2012  ...   2016        IDX
# 66112  METH2012  New income definition since 2012  ...   2017        IDX
# 66113  METH2012  New income definition since 2012  ...   2018        IDX
# 66117  METH2012  New income definition since 2012  ...   2009     0_TO_1
# 66118  METH2012  New income definition since 2012  ...   2010     0_TO_1
# 66119  METH2012  New income definition since 2012  ...   2011     0_TO_1
# 66120  METH2012  New income definition since 2012  ...   2012     0_TO_1
# 66121  METH2012  New income definition since 2012  ...   2013     0_TO_1
# 66122  METH2012  New income definition since 2012  ...   2014     0_TO_1
# 66123  METH2012  New income definition since 2012  ...   2015     0_TO_1
# 66124  METH2012  New income definition since 2012  ...   2016     0_TO_1
# 66125  METH2012  New income definition since 2012  ...   2017     0_TO_1
# 66126  METH2012  New income definition since 2012  ...   2018     0_TO_1
# 66127  METH2012  New income definition since 2012  ...   2018        NBR
# 66128  METH2012  New income definition since 2012  ...   2018        NBR
#
#                     Unit PowerCode Code  PowerCode Reference Period Code  \
# 0              0-1 scale              0      Units                   NaN
# 1              0-1 scale              0      Units                   NaN
# 2              0-1 scale              0      Units                   NaN
# 3              0-1 scale              0      Units                   NaN
# 6              0-1 scale              0      Units                   NaN
# 7              0-1 scale              0      Units                   NaN
# 8                  Index              0      Units                   NaN
# 9                  Index              0      Units                   NaN
# 10                 Index              0      Units                   NaN
# 11                 Index              0      Units                   NaN
# 14                 Index              0      Units                   NaN
# 15                 Index              0      Units                   NaN
# 16                 Ratio              0      Units                   NaN
# 17                 Ratio              0      Units                   NaN
# 18                 Ratio              0      Units                   NaN
# 19                 Ratio              0      Units                   NaN
# 22                 Ratio              0      Units                   NaN
# 23                 Ratio              0      Units                   NaN
# 24     Australian Dollar              0      Units                   NaN
# 25     Australian Dollar              0      Units                   NaN
# 26     Australian Dollar              0      Units                   NaN
# 27     Australian Dollar              0      Units                   NaN
# 30     Australian Dollar              0      Units                   NaN
# 31     Australian Dollar              0      Units                   NaN
# 34     Australian Dollar              0      Units                   NaN
# 35     Australian Dollar              0      Units                   NaN
# 36     Australian Dollar              0      Units                   NaN
# 37     Australian Dollar              0      Units                   NaN
# 38     Australian Dollar              0      Units                   NaN
# 39     Australian Dollar              0      Units                   NaN
# ...                  ...            ...        ...                   ...
# 66093              Ratio              0      Units                   NaN
# 66094              Ratio              0      Units                   NaN
# 66095              Ratio              0      Units                   NaN
# 66096              Ratio              0      Units                   NaN
# 66097              Ratio              0      Units                   NaN
# 66098              Ratio              0      Units                   NaN
# 66099              Ratio              0      Units                   NaN
# 66100              Ratio              0      Units                   NaN
# 66104              Index              0      Units                   NaN
# 66105              Index              0      Units                   NaN
# 66106              Index              0      Units                   NaN
# 66107              Index              0      Units                   NaN
# 66108              Index              0      Units                   NaN
# 66109              Index              0      Units                   NaN
# 66110              Index              0      Units                   NaN
# 66111              Index              0      Units                   NaN
# 66112              Index              0      Units                   NaN
# 66113              Index              0      Units                   NaN
# 66117          0-1 scale              0      Units                   NaN
# 66118          0-1 scale              0      Units                   NaN
# 66119          0-1 scale              0      Units                   NaN
# 66120          0-1 scale              0      Units                   NaN
# 66121          0-1 scale              0      Units                   NaN
# 66122          0-1 scale              0      Units                   NaN
# 66123          0-1 scale              0      Units                   NaN
# 66124          0-1 scale              0      Units                   NaN
# 66125          0-1 scale              0      Units                   NaN
# 66126          0-1 scale              0      Units                   NaN
# 66127             Number              0      Units                   NaN
# 66128             Number              0      Units                   NaN
#
#        Reference Period         Value  Flag Codes Flags
# 0                   NaN  3.260000e-01         NaN   NaN
# 1                   NaN  3.370000e-01         NaN   NaN
# 2                   NaN  3.300000e-01         NaN   NaN
# 3                   NaN  3.250000e-01         NaN   NaN
# 6                   NaN  3.340000e-01         NaN   NaN
# 7                   NaN  3.240000e-01         NaN   NaN
# 8                   NaN  1.051249e+02         NaN   NaN
# 9                   NaN  1.103798e+02         NaN   NaN
# 10                  NaN  1.134756e+02         NaN   NaN
# 11                  NaN  1.178981e+02         NaN   NaN
# 14                  NaN  1.000000e+02         NaN   NaN
# 15                  NaN  1.051249e+02         NaN   NaN
# 16                  NaN  1.290000e-01         NaN   NaN
# 17                  NaN  1.300000e-01         NaN   NaN
# 18                  NaN  1.250000e-01         NaN   NaN
# 19                  NaN  1.330000e-01         NaN   NaN
# 22                  NaN  1.510000e-01         NaN   NaN
# 23                  NaN  1.300000e-01         NaN   NaN
# 24                  NaN  4.792400e+04         NaN   NaN
# 25                  NaN  5.191800e+04         NaN   NaN
# 26                  NaN  5.470900e+04         NaN   NaN
# 27                  NaN  5.669700e+04         NaN   NaN
# 30                  NaN  4.357100e+04         NaN   NaN
# 31                  NaN  4.792400e+04         NaN   NaN
# 34                  NaN  3.376000e+03         NaN   NaN
# 35                  NaN  3.623000e+03         NaN   NaN
# 36                  NaN -1.035800e+04         NaN   NaN
# 37                  NaN -1.320100e+04         NaN   NaN
# 38                  NaN -1.380100e+04         NaN   NaN
# 39                  NaN -1.520200e+04         NaN   NaN
# ...                 ...           ...         ...   ...
# 66093               NaN  2.320000e-01         NaN   NaN
# 66094               NaN  2.430000e-01         NaN   NaN
# 66095               NaN  2.410000e-01         NaN   NaN
# 66096               NaN  2.900000e-01         NaN   NaN
# 66097               NaN  2.580000e-01         NaN   NaN
# 66098               NaN  2.580000e-01         NaN   NaN
# 66099               NaN  2.390000e-01         NaN   NaN
# 66100               NaN  2.550000e-01         NaN   NaN
# 66104               NaN  8.253434e+01         NaN   NaN
# 66105               NaN  8.756185e+01         NaN   NaN
# 66106               NaN  9.263102e+01         NaN   NaN
# 66107               NaN  9.572020e+01         NaN   NaN
# 66108               NaN  9.953437e+01         NaN   NaN
# 66109               NaN  1.005977e+02         NaN   NaN
# 66110               NaN  1.000000e+02         NaN   NaN
# 66111               NaN  9.845520e+01         NaN   NaN
# 66112               NaN  9.977354e+01         NaN   NaN
# 66113               NaN  1.043885e+02         NaN   NaN
# 66117               NaN  7.050000e-01         NaN   NaN
# 66118               NaN  7.100000e-01         NaN   NaN
# 66119               NaN  7.090000e-01         NaN   NaN
# 66120               NaN  7.140000e-01         NaN   NaN
# 66121               NaN  7.280000e-01         NaN   NaN
# 66122               NaN  7.350000e-01         NaN   NaN
# 66123               NaN  7.400000e-01         NaN   NaN
# 66124               NaN  7.690000e-01         NaN   NaN
# 66125               NaN  7.590000e-01         NaN   NaN
# 66126               NaN  7.580000e-01         NaN   NaN
# 66127               NaN  1.346755e+06         NaN   NaN
# 66128               NaN  2.689643e+06         NaN   NaN
#
# [45385 rows x 21 columns]

# %%
cleaned_years_df.count()
# Out:
# LOCATION                 45385
# Country                  45385
# MEASURE                  45385
# Measure                  45385
# AGE                      45385
# Age group                45385
# DEFINITION               45385
# Definition               45385
# METHODO                  45385
# Methodology              45385
# TIME                     45385
# Year                     45385
# Unit Code                45335
# Unit                     45335
# PowerCode Code           45385
# PowerCode                45385
# Reference Period Code        0
# Reference Period             0
# Value                    45385
# Flag Codes                 339
# Flags                      339
# dtype: int64

# %%
cleaned_years_df.dtypes
# Out:
# LOCATION                  object
# Country                   object
# MEASURE                   object
# Measure                   object
# AGE                       object
# Age group                 object
# DEFINITION                object
# Definition                object
# METHODO                   object
# Methodology               object
# TIME                       int64
# Year                       int64
# Unit Code                 object
# Unit                      object
# PowerCode Code             int64
# PowerCode                 object
# Reference Period Code    float64
# Reference Period         float64
# Value                    float64
# Flag Codes                object
# Flags                     object
# dtype: object

# %%
cleaned_years_df.head()
# Out:
#   LOCATION    Country MEASURE  \
# 0      AUS  Australia    GINI
# 1      AUS  Australia    GINI
# 2      AUS  Australia    GINI
# 3      AUS  Australia    GINI
# 6      AUS  Australia    GINI
#
#                                              Measure  AGE         Age group  \
# 0  Gini (disposable income, post taxes and transf...  TOT  Total population
# 1  Gini (disposable income, post taxes and transf...  TOT  Total population
# 2  Gini (disposable income, post taxes and transf...  TOT  Total population
# 3  Gini (disposable income, post taxes and transf...  TOT  Total population
# 6  Gini (disposable income, post taxes and transf...  TOT  Total population
#
#   DEFINITION          Definition   METHODO                       Methodology  \
# 0    CURRENT  Current definition  METH2012  New income definition since 2012
# 1    CURRENT  Current definition  METH2012  New income definition since 2012
# 2    CURRENT  Current definition  METH2012  New income definition since 2012
# 3    CURRENT  Current definition  METH2012  New income definition since 2012
# 6    CURRENT  Current definition  METH2011      Income definition until 2011
#
#    ...   Year  Unit Code       Unit PowerCode Code  PowerCode  \
# 0  ...   2012     0_TO_1  0-1 scale              0      Units
# 1  ...   2014     0_TO_1  0-1 scale              0      Units
# 2  ...   2016     0_TO_1  0-1 scale              0      Units
# 3  ...   2018     0_TO_1  0-1 scale              0      Units
# 6  ...   2010     0_TO_1  0-1 scale              0      Units
#
#   Reference Period Code  Reference Period  Value  Flag Codes Flags
# 0                   NaN               NaN  0.326         NaN   NaN
# 1                   NaN               NaN  0.337         NaN   NaN
# 2                   NaN               NaN  0.330         NaN   NaN
# 3                   NaN               NaN  0.325         NaN   NaN
# 6                   NaN               NaN  0.334         NaN   NaN
#
# [5 rows x 21 columns]

# %%
cleaned_years_df.drop(cleaned_years_df.columns[[0, 3, 4, 6, 7, 8, 9, 10, 14, 15, 16, 17, 19, 20]], axis = 1, inplace = True)
# Out:
# /Users/triciaharris/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
cleaned_years_df
# Out:
#          Country   MEASURE                            Age group  Year  \
# 0      Australia      GINI                     Total population  2012
# 1      Australia      GINI                     Total population  2014
# 2      Australia      GINI                     Total population  2016
# 3      Australia      GINI                     Total population  2018
# 6      Australia      GINI                     Total population  2010
# 7      Australia      GINI                     Total population  2012
# 8      Australia   CPI2010                     Total population  2012
# 9      Australia   CPI2010                     Total population  2014
# 10     Australia   CPI2010                     Total population  2016
# 11     Australia   CPI2010                     Total population  2018
# 14     Australia   CPI2010                     Total population  2010
# 15     Australia   CPI2010                     Total population  2012
# 16     Australia    PVTAA1                     Total population  2012
# 17     Australia    PVTAA1                     Total population  2014
# 18     Australia    PVTAA1                     Total population  2016
# 19     Australia    PVTAA1                     Total population  2018
# 22     Australia    PVTAA1                     Total population  2010
# 23     Australia    PVTAA1                     Total population  2012
# 24     Australia   ECTOTAL                     Total population  2012
# 25     Australia   ECTOTAL                     Total population  2014
# 26     Australia   ECTOTAL                     Total population  2016
# 27     Australia   ECTOTAL                     Total population  2018
# 30     Australia   ECTOTAL                     Total population  2010
# 31     Australia   ECTOTAL                     Total population  2012
# 34     Australia  SECTOTAL                     Total population  2010
# 35     Australia  SECTOTAL                     Total population  2012
# 36     Australia  TACTOTAL                     Total population  2012
# 37     Australia  TACTOTAL                     Total population  2014
# 38     Australia  TACTOTAL                     Total population  2016
# 39     Australia  TACTOTAL                     Total population  2018
# ...          ...       ...                                  ...   ...
# 66093    Romania   PMEAN5A  Retirement age population: above 65  2011
# 66094    Romania   PMEAN5A  Retirement age population: above 65  2012
# 66095    Romania   PMEAN5A  Retirement age population: above 65  2013
# 66096    Romania   PMEAN5A  Retirement age population: above 65  2014
# 66097    Romania   PMEAN5A  Retirement age population: above 65  2015
# 66098    Romania   PMEAN5A  Retirement age population: above 65  2016
# 66099    Romania   PMEAN5A  Retirement age population: above 65  2017
# 66100    Romania   PMEAN5A  Retirement age population: above 65  2018
# 66104    Romania   CPI2015                     Total population  2009
# 66105    Romania   CPI2015                     Total population  2010
# 66106    Romania   CPI2015                     Total population  2011
# 66107    Romania   CPI2015                     Total population  2012
# 66108    Romania   CPI2015                     Total population  2013
# 66109    Romania   CPI2015                     Total population  2014
# 66110    Romania   CPI2015                     Total population  2015
# 66111    Romania   CPI2015                     Total population  2016
# 66112    Romania   CPI2015                     Total population  2017
# 66113    Romania   CPI2015                     Total population  2018
# 66117   Bulgaria     GINIB  Retirement age population: above 65  2009
# 66118   Bulgaria     GINIB  Retirement age population: above 65  2010
# 66119   Bulgaria     GINIB  Retirement age population: above 65  2011
# 66120   Bulgaria     GINIB  Retirement age population: above 65  2012
# 66121   Bulgaria     GINIB  Retirement age population: above 65  2013
# 66122   Bulgaria     GINIB  Retirement age population: above 65  2014
# 66123   Bulgaria     GINIB  Retirement age population: above 65  2015
# 66124   Bulgaria     GINIB  Retirement age population: above 65  2016
# 66125   Bulgaria     GINIB  Retirement age population: above 65  2017
# 66126   Bulgaria     GINIB  Retirement age population: above 65  2018
# 66127     Sweden       HHD  Retirement age population: above 65  2018
# 66128     Sweden       HHD        Working age population: 18-65  2018
#
#       Unit Code               Unit         Value
# 0        0_TO_1          0-1 scale  3.260000e-01
# 1        0_TO_1          0-1 scale  3.370000e-01
# 2        0_TO_1          0-1 scale  3.300000e-01
# 3        0_TO_1          0-1 scale  3.250000e-01
# 6        0_TO_1          0-1 scale  3.340000e-01
# 7        0_TO_1          0-1 scale  3.240000e-01
# 8           IDX              Index  1.051249e+02
# 9           IDX              Index  1.103798e+02
# 10          IDX              Index  1.134756e+02
# 11          IDX              Index  1.178981e+02
# 14          IDX              Index  1.000000e+02
# 15          IDX              Index  1.051249e+02
# 16        RATIO              Ratio  1.290000e-01
# 17        RATIO              Ratio  1.300000e-01
# 18        RATIO              Ratio  1.250000e-01
# 19        RATIO              Ratio  1.330000e-01
# 22        RATIO              Ratio  1.510000e-01
# 23        RATIO              Ratio  1.300000e-01
# 24          AUD  Australian Dollar  4.792400e+04
# 25          AUD  Australian Dollar  5.191800e+04
# 26          AUD  Australian Dollar  5.470900e+04
# 27          AUD  Australian Dollar  5.669700e+04
# 30          AUD  Australian Dollar  4.357100e+04
# 31          AUD  Australian Dollar  4.792400e+04
# 34          AUD  Australian Dollar  3.376000e+03
# 35          AUD  Australian Dollar  3.623000e+03
# 36          AUD  Australian Dollar -1.035800e+04
# 37          AUD  Australian Dollar -1.320100e+04
# 38          AUD  Australian Dollar -1.380100e+04
# 39          AUD  Australian Dollar -1.520200e+04
# ...         ...                ...           ...
# 66093     RATIO              Ratio  2.320000e-01
# 66094     RATIO              Ratio  2.430000e-01
# 66095     RATIO              Ratio  2.410000e-01
# 66096     RATIO              Ratio  2.900000e-01
# 66097     RATIO              Ratio  2.580000e-01
# 66098     RATIO              Ratio  2.580000e-01
# 66099     RATIO              Ratio  2.390000e-01
# 66100     RATIO              Ratio  2.550000e-01
# 66104       IDX              Index  8.253434e+01
# 66105       IDX              Index  8.756185e+01
# 66106       IDX              Index  9.263102e+01
# 66107       IDX              Index  9.572020e+01
# 66108       IDX              Index  9.953437e+01
# 66109       IDX              Index  1.005977e+02
# 66110       IDX              Index  1.000000e+02
# 66111       IDX              Index  9.845520e+01
# 66112       IDX              Index  9.977354e+01
# 66113       IDX              Index  1.043885e+02
# 66117    0_TO_1          0-1 scale  7.050000e-01
# 66118    0_TO_1          0-1 scale  7.100000e-01
# 66119    0_TO_1          0-1 scale  7.090000e-01
# 66120    0_TO_1          0-1 scale  7.140000e-01
# 66121    0_TO_1          0-1 scale  7.280000e-01
# 66122    0_TO_1          0-1 scale  7.350000e-01
# 66123    0_TO_1          0-1 scale  7.400000e-01
# 66124    0_TO_1          0-1 scale  7.690000e-01
# 66125    0_TO_1          0-1 scale  7.590000e-01
# 66126    0_TO_1          0-1 scale  7.580000e-01
# 66127       NBR             Number  1.346755e+06
# 66128       NBR             Number  2.689643e+06
#
# [45385 rows x 7 columns]

# %%
gini_cpi = cleaned_years_df[cleaned_years_df["MEASURE"].isin(["GINI","CPI2010", "CPI2015"])]

# %%
gini_cpi.count()
# Out:
# Country      3906
# MEASURE      3906
# Age group    3906
# Year         3906
# Unit Code    3906
# Unit         3906
# Value        3906
# dtype: int64

# %%
gini_cpi
# Out:
#          Country  MEASURE                            Age group  Year  \
# 0      Australia     GINI                     Total population  2012
# 1      Australia     GINI                     Total population  2014
# 2      Australia     GINI                     Total population  2016
# 3      Australia     GINI                     Total population  2018
# 6      Australia     GINI                     Total population  2010
# 7      Australia     GINI                     Total population  2012
# 8      Australia  CPI2010                     Total population  2012
# 9      Australia  CPI2010                     Total population  2014
# 10     Australia  CPI2010                     Total population  2016
# 11     Australia  CPI2010                     Total population  2018
# 14     Australia  CPI2010                     Total population  2010
# 15     Australia  CPI2010                     Total population  2012
# 390      Austria     GINI                     Total population  2009
# 391      Austria     GINI                     Total population  2010
# 392      Austria     GINI                     Total population  2011
# 393      Austria     GINI                     Total population  2012
# 394      Austria     GINI                     Total population  2013
# 395      Austria     GINI                     Total population  2014
# 396      Austria     GINI                     Total population  2015
# 397      Austria     GINI                     Total population  2016
# 398      Austria     GINI                     Total population  2017
# 399      Austria     GINI                     Total population  2018
# 402      Austria  CPI2010                     Total population  2009
# 403      Austria  CPI2010                     Total population  2010
# 404      Austria  CPI2010                     Total population  2011
# 405      Austria  CPI2010                     Total population  2012
# 406      Austria  CPI2010                     Total population  2013
# 407      Austria  CPI2010                     Total population  2014
# 408      Austria  CPI2010                     Total population  2015
# 409      Austria  CPI2010                     Total population  2016
# ...          ...      ...                                  ...   ...
# 66039   Bulgaria     GINI  Retirement age population: above 65  2009
# 66040   Bulgaria     GINI  Retirement age population: above 65  2010
# 66041   Bulgaria     GINI  Retirement age population: above 65  2011
# 66042   Bulgaria     GINI  Retirement age population: above 65  2012
# 66043   Bulgaria     GINI  Retirement age population: above 65  2013
# 66044   Bulgaria     GINI  Retirement age population: above 65  2014
# 66045   Bulgaria     GINI  Retirement age population: above 65  2015
# 66046   Bulgaria     GINI  Retirement age population: above 65  2016
# 66047   Bulgaria     GINI  Retirement age population: above 65  2017
# 66048   Bulgaria     GINI  Retirement age population: above 65  2018
# 66065   Bulgaria     GINI        Working age population: 18-65  2009
# 66066   Bulgaria     GINI        Working age population: 18-65  2010
# 66067   Bulgaria     GINI        Working age population: 18-65  2011
# 66068   Bulgaria     GINI        Working age population: 18-65  2012
# 66069   Bulgaria     GINI        Working age population: 18-65  2013
# 66070   Bulgaria     GINI        Working age population: 18-65  2014
# 66071   Bulgaria     GINI        Working age population: 18-65  2015
# 66072   Bulgaria     GINI        Working age population: 18-65  2016
# 66073   Bulgaria     GINI        Working age population: 18-65  2017
# 66074   Bulgaria     GINI        Working age population: 18-65  2018
# 66104    Romania  CPI2015                     Total population  2009
# 66105    Romania  CPI2015                     Total population  2010
# 66106    Romania  CPI2015                     Total population  2011
# 66107    Romania  CPI2015                     Total population  2012
# 66108    Romania  CPI2015                     Total population  2013
# 66109    Romania  CPI2015                     Total population  2014
# 66110    Romania  CPI2015                     Total population  2015
# 66111    Romania  CPI2015                     Total population  2016
# 66112    Romania  CPI2015                     Total population  2017
# 66113    Romania  CPI2015                     Total population  2018
#
#       Unit Code       Unit       Value
# 0        0_TO_1  0-1 scale    0.326000
# 1        0_TO_1  0-1 scale    0.337000
# 2        0_TO_1  0-1 scale    0.330000
# 3        0_TO_1  0-1 scale    0.325000
# 6        0_TO_1  0-1 scale    0.334000
# 7        0_TO_1  0-1 scale    0.324000
# 8           IDX      Index  105.124871
# 9           IDX      Index  110.379814
# 10          IDX      Index  113.475554
# 11          IDX      Index  117.898072
# 14          IDX      Index  100.000000
# 15          IDX      Index  105.124871
# 390      0_TO_1  0-1 scale    0.289000
# 391      0_TO_1  0-1 scale    0.280000
# 392      0_TO_1  0-1 scale    0.281000
# 393      0_TO_1  0-1 scale    0.276000
# 394      0_TO_1  0-1 scale    0.280000
# 395      0_TO_1  0-1 scale    0.274000
# 396      0_TO_1  0-1 scale    0.275000
# 397      0_TO_1  0-1 scale    0.284000
# 398      0_TO_1  0-1 scale    0.275000
# 399      0_TO_1  0-1 scale    0.280000
# 402         IDX      Index   98.218771
# 403         IDX      Index  100.000000
# 404         IDX      Index  103.286591
# 405         IDX      Index  105.853953
# 406         IDX      Index  107.971205
# 407         IDX      Index  109.705008
# 408         IDX      Index  110.688550
# 409         IDX      Index  111.675477
# ...         ...        ...         ...
# 66039    0_TO_1  0-1 scale    0.309000
# 66040    0_TO_1  0-1 scale    0.319000
# 66041    0_TO_1  0-1 scale    0.311000
# 66042    0_TO_1  0-1 scale    0.323000
# 66043    0_TO_1  0-1 scale    0.302000
# 66044    0_TO_1  0-1 scale    0.314000
# 66045    0_TO_1  0-1 scale    0.302000
# 66046    0_TO_1  0-1 scale    0.339000
# 66047    0_TO_1  0-1 scale    0.340000
# 66048    0_TO_1  0-1 scale    0.343000
# 66065    0_TO_1  0-1 scale    0.316000
# 66066    0_TO_1  0-1 scale    0.316000
# 66067    0_TO_1  0-1 scale    0.331000
# 66068    0_TO_1  0-1 scale    0.349000
# 66069    0_TO_1  0-1 scale    0.351000
# 66070    0_TO_1  0-1 scale    0.362000
# 66071    0_TO_1  0-1 scale    0.378000
# 66072    0_TO_1  0-1 scale    0.396000
# 66073    0_TO_1  0-1 scale    0.392000
# 66074    0_TO_1  0-1 scale    0.400000
# 66104       IDX      Index   82.534337
# 66105       IDX      Index   87.561847
# 66106       IDX      Index   92.631025
# 66107       IDX      Index   95.720198
# 66108       IDX      Index   99.534372
# 66109       IDX      Index  100.597708
# 66110       IDX      Index  100.000000
# 66111       IDX      Index   98.455203
# 66112       IDX      Index   99.773539
# 66113       IDX      Index  104.388549
#
# [3906 rows x 7 columns]

# %%
#export to csv 
gini_cpi.to_csv('gini_cpi.csv', header=True, index=True)

# %%
# read csv - from Simon - assess CPI
file_path=os.path.join('data_working.csv')
working_df=pd.read_csv(file_path)
working_df.head()
# Out:
#    Unnamed: 0  Country  Year  Union %   Gini         CPI
# 0           0  Hungary  2009     11.9  0.245   95.369304
# 1           1  Hungary  2015      9.0  0.291  111.384411
# 2           2   Poland  2009     16.3  0.305   97.484226
# 3           3   Poland  2010     18.3  0.307  100.000000
# 4           4   Poland  2011     17.0  0.304  104.239401

# %%
cleaned=working_df.drop("Unnamed: 0", axis=1)

# %%
cleaned.head()
# Out:
#    Country  Year  Union %   Gini         CPI
# 0  Hungary  2009     11.9  0.245   95.369304
# 1  Hungary  2015      9.0  0.291  111.384411
# 2   Poland  2009     16.3  0.305   97.484226
# 3   Poland  2010     18.3  0.307  100.000000
# 4   Poland  2011     17.0  0.304  104.239401

# %%
cleaned.describe()
# Out:
#               Year     Union %        Gini         CPI
# count   274.000000  274.000000  274.000000  274.000000
# mean   2013.178832   27.405839    0.306745  106.253553
# std       2.753777   21.074236    0.047903    6.242617
# min    2009.000000    4.300000    0.233000   94.879602
# 25%    2011.000000   12.700000    0.268250  101.143633
# 50%    2013.000000   18.350000    0.299000  106.295550
# 75%    2015.750000   33.450000    0.335000  109.106306
# max    2018.000000   91.000000    0.514000  146.067818

# %%
# put countries into groups
west = ['United Kingdom', 'Spain', 'Austria', 'France', 'Germany', 'Ireland', 'Switzerland', 'Italy', 'Luxembourg', 'Greece', 'Israel'
                 'Netherlands', 'Belgium', 'Australia', 'New Zealand', 'Portugal', 'Turkey', 'Canada']
east =  ['Estonia', 'Czech Republic', 'Latvia', 'Lithuania', 'Hungary', 'Slovak Republic', 'Slovenia', 'Poland'] 
scandinavian = ['Norway', 'Finland' ,'Iceland', 'Sweden', 'Denmark']
us = ['United States']
asia = ['Korea', 'Japan']
latin = ['Mexico', 'Chile']

# %%
west_df = pd.DataFrame({"Country": west})
east_df = pd.DataFrame({"Country": east})
scand_df = pd.DataFrame({"Country": scandinavian})
us_df = pd.DataFrame({"Country": us})
asia_df = pd.DataFrame({"Country": asia})
latin_df = pd.DataFrame({"Country": latin})

# %%
# cleaned[cleaned["Country"] == west_df["Country"]]

west_filter = pd.merge(cleaned, west_df, on=["Country"])
east_filter = pd.merge(cleaned, east_df, on=["Country"])
scand_filter = pd.merge(cleaned, scand_df, on=["Country"])
us_filter = pd.merge(cleaned, us_df, on=["Country"])
asia_filter = pd.merge(cleaned, asia_df, on=["Country"])
latin_filter = pd.merge(cleaned, latin_df, on=["Country"])

df = {
    "west": {"df": west_filter, "x":0, "y":0},
    "east": {"df": east_filter, "x":0, "y":1},
    "scand": {"df":scand_filter, "x":1, "y":0},
    "us": {"df":us_filter, "x":1, "y":1},
    "asia": {"df":asia_filter, "x":2, "y":0},
    "latin": {"df":latin_filter, "x":2, "y":1}
}

# %%
cleaned.head()
# Out:
#    Country  Year  Union %   Gini         CPI
# 0  Hungary  2009     11.9  0.245   95.369304
# 1  Hungary  2015      9.0  0.291  111.384411
# 2   Poland  2009     16.3  0.305   97.484226
# 3   Poland  2010     18.3  0.307  100.000000
# 4   Poland  2011     17.0  0.304  104.239401

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))

for region in df:
    x_position=df[region]["x"]
    y_position=df[region]["y"]
    df[region]["df"].plot.scatter(x="Union %", y="CPI", ax=ax[x_position][y_position], grid=True)
    ax[x_position][y_position].set_title(region)
    ax[x_position][y_position].set_ylim(80, 160)
    ax[x_position][y_position].set_xlim(0, 60)
