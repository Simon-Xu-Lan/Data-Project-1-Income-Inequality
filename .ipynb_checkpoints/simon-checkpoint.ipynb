# %%
import pandas as pd
import matplotlib.pyplot as plt
from utility import check_columns
import scipy.stats as st

# %%
income_data = pd.read_csv("./raw_data/income_Distribution_OECD_013021.csv")
income_data.head()
# Out:
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   LOCATION    Country MEASURE  \
# 0      AUS  Australia    GINI
# 1      AUS  Australia    GINI
# 2      AUS  Australia    GINI
# 3      AUS  Australia    GINI
# 4      AUS  Australia    GINI
#
#                                              Measure  AGE         Age group  \
# 0  Gini (disposable income, post taxes and transf...  TOT  Total population
# 1  Gini (disposable income, post taxes and transf...  TOT  Total population
# 2  Gini (disposable income, post taxes and transf...  TOT  Total population
# 3  Gini (disposable income, post taxes and transf...  TOT  Total population
# 4  Gini (disposable income, post taxes and transf...  TOT  Total population
#
#   DEFINITION          Definition   METHODO                       Methodology  \
# 0    CURRENT  Current definition  METH2012  New income definition since 2012
# 1    CURRENT  Current definition  METH2012  New income definition since 2012
# 2    CURRENT  Current definition  METH2012  New income definition since 2012
# 3    CURRENT  Current definition  METH2012  New income definition since 2012
# 4    CURRENT  Current definition  METH2011      Income definition until 2011
#
#    ...  Year  Unit Code       Unit PowerCode Code  PowerCode  \
# 0  ...  2012     0_TO_1  0-1 scale              0      Units
# 1  ...  2014     0_TO_1  0-1 scale              0      Units
# 2  ...  2016     0_TO_1  0-1 scale              0      Units
# 3  ...  2018     0_TO_1  0-1 scale              0      Units
# 4  ...  2004     0_TO_1  0-1 scale              0      Units
#
#   Reference Period Code  Reference Period  Value  Flag Codes Flags
# 0                   NaN               NaN  0.326         NaN   NaN
# 1                   NaN               NaN  0.337         NaN   NaN
# 2                   NaN               NaN  0.330         NaN   NaN
# 3                   NaN               NaN  0.325         NaN   NaN
# 4                   NaN               NaN  0.315         NaN   NaN
#
# [5 rows x 21 columns]

# %%
check_columns(income_data, 5)
# Out:
# ============================================================
# Column: LOCATION
# --------------------
# --- Total Unique Values: 44 ---
# SVK    2610
# SVN    2610
# CZE    2610
# LTU    2607
# LVA    2586
# Min: AUS,  Max: ZAF
# ============================================================
# Column: Country
# --------------------
# --- Total Unique Values: 44 ---
# Slovenia           2610
# Czech Republic     2610
# Slovak Republic    2610
# Lithuania          2607
# Latvia             2586
# Min: Australia,  Max: United States
# ============================================================
# Column: MEASURE
# --------------------
# --- Total Unique Values: 60 ---
# GINI       1937
# CPI2015    1937
# PPPPRC     1937
# CPI2010    1937
# MEDIANC    1914
# Min: CPI2010,  Max: TRRCTOTAL
# ============================================================
# Column: Measure
# --------------------
# --- Total Unique Values: 60 ---
# Consumer Price Index (base 2015=100)                  1937
# Gini (disposable income, post taxes and transfers)    1937
# Purchasing Power Parities for private consumption     1937
# Consumer Price Index (base 2010=100)                  1937
# Median disposable income (current prices)             1914
# Min: Age group 0-17: Poverty rate after taxes and transfers,  Max: Total number of individuals
# ============================================================
# Column: AGE
# --------------------
# --- Total Unique Values: 3 ---
# TOT    31872
# WA     18079
# OLD    16178
# Min: OLD,  Max: WA
# ============================================================
# Column: Age group
# --------------------
# --- Total Unique Values: 3 ---
# Total population                       31872
# Working age population: 18-65          18079
# Retirement age population: above 65    16178
# Min: Retirement age population: above 65,  Max: Working age population: 18-65
# ============================================================
# Column: DEFINITION
# --------------------
# --- Total Unique Values: 1 ---
# CURRENT    66129
# Min: CURRENT,  Max: CURRENT
# ============================================================
# Column: Definition
# --------------------
# --- Total Unique Values: 1 ---
# Current definition    66129
# Min: Current definition,  Max: Current definition
# ============================================================
# Column: METHODO
# --------------------
# --- Total Unique Values: 2 ---
# METH2012    42526
# METH2011    23603
# Min: METH2011,  Max: METH2012
# ============================================================
# Column: Methodology
# --------------------
# --- Total Unique Values: 2 ---
# New income definition since 2012    42526
# Income definition until 2011        23603
# Min: Income definition until 2011,  Max: New income definition since 2012
# ============================================================
# Column: TIME
# --------------------
# --- Total Unique Values: 16 ---
# 2011    6302
# 2009    5650
# 2012    5547
# 2010    5259
# 2008    5228
# Min: 2004,  Max: 2019
# ============================================================
# Column: Year
# --------------------
# --- Total Unique Values: 16 ---
# 2011    6302
# 2009    5650
# 2012    5547
# 2010    5259
# 2008    5228
# Min: 2004,  Max: 2019
# ============================================================
# Column: Unit Code
# --------------------
# --- Total Unique Values: 38 ---
# RATIO     26327
# EUR       10907
# IDX        3874
# 0_TO_1     3797
# NATUSD     1937
# Min: 0_TO_1,  Max: ZAR
# ============================================================
# Column: Unit
# --------------------
# --- Total Unique Values: 38 ---
# Ratio                              26327
# Euro                               10907
# Index                               3874
# 0-1 scale                           3797
# National currency per US dollar     1937
# Min: 0-1 scale,  Max: Zloty
# ============================================================
# Column: PowerCode Code
# --------------------
# --- Total Unique Values: 1 ---
# 0    66129
# Min: 0,  Max: 0
# ============================================================
# Column: PowerCode
# --------------------
# --- Total Unique Values: 1 ---
# Units    66129
# Min: Units,  Max: Units
# ============================================================
# Column: Reference Period Code
# --------------------
# --- Total Unique Values: 0 ---
# Series([], )
# Min: nan,  Max: nan
# ============================================================
# Column: Reference Period
# --------------------
# --- Total Unique Values: 0 ---
# Series([], )
# Min: nan,  Max: nan
# ============================================================
# Column: Value
# --------------------
# --- Total Unique Values: 21695 ---
# 1.9    588
# 1.8    538
# 2.0    433
# 1.7    402
# 2.1    330
# Min: -6530000.0,  Max: 1206910494.0
# ============================================================
# Column: Flag Codes
# --------------------
# --- Total Unique Values: 2 ---
# P    222
# i    117
# Min: P,  Max: i
# ============================================================
# Column: Flags
# --------------------
# --- Total Unique Values: 2 ---
# Provisional value                  222
# post taxes and before transfers    117
# Min: Provisional value,  Max: post taxes and before transfers

# %%
clean_income = income_data[['LOCATION', 'Country', 'Measure', 'Age group', 'Methodology', 'Year', 'Unit', 'Value']]
clean_income
# Out:
#       LOCATION    Country                                            Measure  \
# 0          AUS  Australia  Gini (disposable income, post taxes and transf...
# 1          AUS  Australia  Gini (disposable income, post taxes and transf...
# 2          AUS  Australia  Gini (disposable income, post taxes and transf...
# 3          AUS  Australia  Gini (disposable income, post taxes and transf...
# 4          AUS  Australia  Gini (disposable income, post taxes and transf...
# ...        ...        ...                                                ...
# 66124      BGR   Bulgaria   Gini (market income, before taxes and transfers)
# 66125      BGR   Bulgaria   Gini (market income, before taxes and transfers)
# 66126      BGR   Bulgaria   Gini (market income, before taxes and transfers)
# 66127      SWE     Sweden                         Total number of households
# 66128      SWE     Sweden                         Total number of households
#
#                                  Age group                       Methodology  \
# 0                         Total population  New income definition since 2012
# 1                         Total population  New income definition since 2012
# 2                         Total population  New income definition since 2012
# 3                         Total population  New income definition since 2012
# 4                         Total population      Income definition until 2011
# ...                                    ...                               ...
# 66124  Retirement age population: above 65  New income definition since 2012
# 66125  Retirement age population: above 65  New income definition since 2012
# 66126  Retirement age population: above 65  New income definition since 2012
# 66127  Retirement age population: above 65  New income definition since 2012
# 66128        Working age population: 18-65  New income definition since 2012
#
#        Year       Unit        Value
# 0      2012  0-1 scale        0.326
# 1      2014  0-1 scale        0.337
# 2      2016  0-1 scale        0.330
# 3      2018  0-1 scale        0.325
# 4      2004  0-1 scale        0.315
# ...     ...        ...          ...
# 66124  2016  0-1 scale        0.769
# 66125  2017  0-1 scale        0.759
# 66126  2018  0-1 scale        0.758
# 66127  2018     Number  1346755.000
# 66128  2018     Number  2689643.000
#
# [66129 rows x 8 columns]

# %%
clean_income["Measure"].value_counts()
# Out:
# Consumer Price Index (base 2015=100)                                                                     1937
# Gini (disposable income, post taxes and transfers)                                                       1937
# Purchasing Power Parities for private consumption                                                        1937
# Consumer Price Index (base 2010=100)                                                                     1937
# Median disposable income (current prices)                                                                1914
# Poverty rate after taxes and transfers, Poverty line 50%                                                 1910
# Total number of individuals                                                                              1884
# Poverty rate after taxes and transfers, Poverty line 60%                                                 1876
# Mean Poverty gap after taxes and transfers, Poverty line 50%                                             1873
# Mean Poverty gap after taxes and transfers, Poverty line 60%                                             1873
# Poverty rate before taxes and transfers, Poverty line 50%                                                1868
# Gini (market income, before taxes and transfers)                                                         1860
# Poverty rate before taxes and transfers, Poverty line 60%                                                1853
# P50/P10  disposable income decile ratio                                                                  1836
# P90/P50  disposable income decile ratio                                                                  1836
# S80/S20 disposable income quintile share                                                                 1836
# Palma ratio                                                                                              1836
# P90/P10 disposable income decile ratio                                                                   1836
# Mean disposable income (current prices)                                                                  1835
# Taxes and social security contributions paid directly by households (Current prices)                     1773
# Total earnings (current prices)                                                                          1771
# Income from self-employment (current prices)                                                             1746
# Current transfers received (Current prices)                                                              1193
# Capital income (current prices)                                                                          1193
# Income from self-employment and from goods produced for own consumption (current prices)                 1166
# Current transfers paid (Current prices)                                                                  1163
# Current transfers paid by households to non-profit institutions and other households (Current prices)    1112
# Total number of households                                                                                914
# Income from own consumption (Current prices)                                                              657
# Median Poverty gap after taxes and transfers, Poverty line 60%                                            646
# Median Poverty gap after taxes and transfers, Poverty line 50%                                            645
# Age group 76+: share                                                                                      638
# Age group 66-75: mean disposable income (current prices)                                                  638
# Age group 41-50: share                                                                                    638
# Age group 51-65: share                                                                                    638
# Age group 26-40: Poverty rate after taxes and transfers                                                   638
# Age group 0-17: share                                                                                     638
# Age group 66-75: Poverty rate after taxes and transfers                                                   638
# Age group 18-25: mean disposable income (current prices)                                                  638
# Age group 0-17: Poverty rate after taxes and transfers                                                    638
# Age group 41-50: mean disposable income (current prices)                                                  638
# Age group 51-65: Poverty rate after taxes and transfers                                                   638
# Age group 41-50: Poverty rate after taxes and transfers                                                   638
# Age group 18-25: share                                                                                    638
# Age group 66-75: share                                                                                    638
# Age group 26-40: mean disposable income (current prices)                                                  638
# Age group 0-17: mean disposable income (current prices)                                                   638
# Age group 18-25: Poverty rate after taxes and transfers                                                   638
# Age group 26-40: share                                                                                    638
# Age group 51-65: mean disposable income (current prices)                                                  638
# Capital and private transfers (current prices)                                                            637
# Age group 76+: Poverty rate after taxes and transfers                                                     632
# Age group 76+: mean disposable income (current prices)                                                    632
# All  working-age household types: Poverty rate after taxes and transfers                                  402
# All age groups: Poverty rate after taxes and transfers                                                    394
# All age groups: mean disposable income (current prices)                                                   394
# All  working-age household types: Poverty rate before taxes and transfers                                 393
# Standard error Gini (post taxes and transfers)                                                            378
# Contributions paid by households to employment-related social insurance schemes (Current prices)          252
# All working-age household types: mean disposable income (current prices)                                  240
# Name: Measure, dtype: int64

# %%
gini_df = pd.DataFrame()
for column in clean_income.columns:
    gini_df[column] = ""
for index, row in clean_income.iterrows():
    if (row["Measure"]).startswith("Gini"):
        gini_df.loc[index, :]  = row
gini_df
# Out:
#       LOCATION    Country                                            Measure  \
# 0          AUS  Australia  Gini (disposable income, post taxes and transf...
# 1          AUS  Australia  Gini (disposable income, post taxes and transf...
# 2          AUS  Australia  Gini (disposable income, post taxes and transf...
# 3          AUS  Australia  Gini (disposable income, post taxes and transf...
# 4          AUS  Australia  Gini (disposable income, post taxes and transf...
# ...        ...        ...                                                ...
# 66122      BGR   Bulgaria   Gini (market income, before taxes and transfers)
# 66123      BGR   Bulgaria   Gini (market income, before taxes and transfers)
# 66124      BGR   Bulgaria   Gini (market income, before taxes and transfers)
# 66125      BGR   Bulgaria   Gini (market income, before taxes and transfers)
# 66126      BGR   Bulgaria   Gini (market income, before taxes and transfers)
#
#                                  Age group                       Methodology  \
# 0                         Total population  New income definition since 2012
# 1                         Total population  New income definition since 2012
# 2                         Total population  New income definition since 2012
# 3                         Total population  New income definition since 2012
# 4                         Total population      Income definition until 2011
# ...                                    ...                               ...
# 66122  Retirement age population: above 65  New income definition since 2012
# 66123  Retirement age population: above 65  New income definition since 2012
# 66124  Retirement age population: above 65  New income definition since 2012
# 66125  Retirement age population: above 65  New income definition since 2012
# 66126  Retirement age population: above 65  New income definition since 2012
#
#        Year       Unit  Value
# 0      2012  0-1 scale  0.326
# 1      2014  0-1 scale  0.337
# 2      2016  0-1 scale   0.33
# 3      2018  0-1 scale  0.325
# 4      2004  0-1 scale  0.315
# ...     ...        ...    ...
# 66122  2014  0-1 scale  0.735
# 66123  2015  0-1 scale   0.74
# 66124  2016  0-1 scale  0.769
# 66125  2017  0-1 scale  0.759
# 66126  2018  0-1 scale  0.758
#
# [3797 rows x 8 columns]

# %%
gini_df[["Country", "Value"]].set_index("Country").plot(kind="bar", figsize=(20,2))
plt.show()

# %%
gini_years = gini_df["Year"].value_counts().index
print(gini_years.min())
print(gini_years.max())
# Out:
# 2004
# 2019

# %%
data_2018_df = ""
df = gini_df[gini_df["Year"] == 2018]
df[df["Age group"] == "Total population"]["Country"].value_counts()
# Out:
# United Kingdom     2
# Luxembourg         2
# Slovak Republic    2
# Slovenia           2
# Costa Rica         2
# Australia          2
# Lithuania          2
# Sweden             2
# Latvia             2
# Romania            2
# Belgium            2
# Norway             2
# Portugal           2
# Canada             2
# Poland             2
# Greece             2
# Spain              2
# Czech Republic     2
# Austria            2
# Bulgaria           2
# Finland            2
# Estonia            2
# Korea              2
# Hungary            2
# France             2
# Israel             2
# Name: Country, dtype: int64

# %% [markdown]
# ## Tud data from tud_30012021192028220.csv

# %%
tud_df = pd.read_csv("raw_data/tud_30012021192028220.csv")
tud_df
# Out:
#       COU    Country SOURCE               Source SERIES         Series  TIME  \
# 0     HUN    Hungary    ADM  Administrative data    EEM      Employees  1998
# 1     HUN    Hungary    ADM  Administrative data    EEM      Employees  2000
# 2     HUN    Hungary    ADM  Administrative data    EEM      Employees  2001
# 3     HUN    Hungary    ADM  Administrative data    EEM      Employees  2003
# 4     HUN    Hungary    ADM  Administrative data    EEM      Employees  2005
# ...   ...        ...    ...                  ...    ...            ...   ...
# 2514  AUS  Australia    ADM  Administrative data    TUM  Union members  2000
# 2515  AUS  Australia    ADM  Administrative data    TUM  Union members  2003
# 2516  AUS  Australia    ADM  Administrative data    TUM  Union members  2008
# 2517  AUS  Australia    ADM  Administrative data    TUM  Union members  2013
# 2518  AUS  Australia    ADM  Administrative data    TUM  Union members  2017
#
#       Year Unit Code    Unit  PowerCode Code  PowerCode  \
# 0     1998       NBR  Number               3  Thousands
# 1     2000       NBR  Number               3  Thousands
# 2     2001       NBR  Number               3  Thousands
# 3     2003       NBR  Number               3  Thousands
# 4     2005       NBR  Number               3  Thousands
# ...    ...       ...     ...             ...        ...
# 2514  2000       NBR  Number               3  Thousands
# 2515  2003       NBR  Number               3  Thousands
# 2516  2008       NBR  Number               3  Thousands
# 2517  2013       NBR  Number               3  Thousands
# 2518  2017       NBR  Number               3  Thousands
#
#       Reference Period Code  Reference Period   Value Flag Codes Flags
# 0                       NaN               NaN  3088.0        NaN   NaN
# 1                       NaN               NaN  3256.0        NaN   NaN
# 2                       NaN               NaN  3314.0        NaN   NaN
# 3                       NaN               NaN  3399.0        NaN   NaN
# 4                       NaN               NaN  3367.0        NaN   NaN
# ...                     ...               ...     ...        ...   ...
# 2514                    NaN               NaN  1911.0        NaN   NaN
# 2515                    NaN               NaN  1890.0        NaN   NaN
# 2516                    NaN               NaN  1762.0        NaN   NaN
# 2517                    NaN               NaN  1756.0        NaN   NaN
# 2518                    NaN               NaN  1620.0        NaN   NaN
#
# [2519 rows x 17 columns]

# %%
check_columns(tud_df, 5)
# Out:
# ============================================================
# Column: COU
# --------------------
# --- Total Unique Values: 36 ---
# GBR    126
# SWE    123
# CAN    117
# EST    114
# NLD    111
# Min: AUS,  Max: USA
# ============================================================
# Column: Country
# --------------------
# --- Total Unique Values: 36 ---
# United Kingdom    126
# Sweden            123
# Canada            117
# Estonia           114
# Netherlands       111
# Min: Australia,  Max: United States
# ============================================================
# Column: SOURCE
# --------------------
# --- Total Unique Values: 2 ---
# ADM    1797
# SVY     722
# Min: ADM,  Max: SVY
# ============================================================
# Column: Source
# --------------------
# --- Total Unique Values: 2 ---
# Administrative data    1797
# Survey data             722
# Min: Administrative data,  Max: Survey data
# ============================================================
# Column: SERIES
# --------------------
# --- Total Unique Values: 3 ---
# TUD    851
# EEM    834
# TUM    834
# Min: EEM,  Max: TUM
# ============================================================
# Column: Series
# --------------------
# --- Total Unique Values: 3 ---
# Trade union  density    851
# Employees               834
# Union members           834
# Min: Employees,  Max: Union members
# ============================================================
# Column: TIME
# --------------------
# --- Total Unique Values: 21 ---
# 2008    140
# 2013    136
# 2016    133
# 2010    131
# 2012    126
# Min: 1998,  Max: 2018
# ============================================================
# Column: Year
# --------------------
# --- Total Unique Values: 21 ---
# 2008    140
# 2013    136
# 2016    133
# 2010    131
# 2012    126
# Min: 1998,  Max: 2018
# ============================================================
# Column: Unit Code
# --------------------
# --- Total Unique Values: 2 ---
# NBR    1668
# PC      851
# Min: NBR,  Max: PC
# ============================================================
# Column: Unit
# --------------------
# --- Total Unique Values: 2 ---
# Number        1668
# Percentage     851
# Min: Number,  Max: Percentage
# ============================================================
# Column: PowerCode Code
# --------------------
# --- Total Unique Values: 2 ---
# 3    1668
# 0     851
# Min: 0,  Max: 3
# ============================================================
# Column: PowerCode
# --------------------
# --- Total Unique Values: 2 ---
# Thousands    1668
# Units         851
# Min: Thousands,  Max: Units
# ============================================================
# Column: Reference Period Code
# --------------------
# --- Total Unique Values: 0 ---
# Series([], )
# Min: nan,  Max: nan
# ============================================================
# Column: Reference Period
# --------------------
# --- Total Unique Values: 0 ---
# Series([], )
# Min: nan,  Max: nan
# ============================================================
# Column: Value
# --------------------
# --- Total Unique Values: 1809 ---
# 10.8     9
# 9.0      7
# 17.9     7
# 544.0    7
# 18.8     7
# Min: 4.3,  Max: 145958.0
# ============================================================
# Column: Flag Codes
# --------------------
# --- Total Unique Values: 2 ---
# B    17
# E    13
# Min: B,  Max: E
# ============================================================
# Column: Flags
# --------------------
# --- Total Unique Values: 2 ---
# Break              17
# Estimated value    13
# Min: Break,  Max: Estimated value

# %%
tud_df["Series"].value_counts()
# Out:
# Trade union  density    851
# Employees               834
# Union members           834
# Name: Series, dtype: int64

# %%
tud_df[tud_df["COU"] == "USA"]
# Out:
#       COU        Country SOURCE       Source SERIES                Series  \
# 333   USA  United States    SVY  Survey data    EEM             Employees
# 334   USA  United States    SVY  Survey data    EEM             Employees
# 335   USA  United States    SVY  Survey data    EEM             Employees
# 336   USA  United States    SVY  Survey data    EEM             Employees
# 337   USA  United States    SVY  Survey data    EEM             Employees
# ...   ...            ...    ...          ...    ...                   ...
# 2422  USA  United States    SVY  Survey data    TUD  Trade union  density
# 2423  USA  United States    SVY  Survey data    TUD  Trade union  density
# 2424  USA  United States    SVY  Survey data    TUD  Trade union  density
# 2425  USA  United States    SVY  Survey data    TUD  Trade union  density
# 2426  USA  United States    SVY  Survey data    TUD  Trade union  density
#
#       TIME  Year Unit Code        Unit  PowerCode Code  PowerCode  \
# 333   1998  1998       NBR      Number               3  Thousands
# 334   1999  1999       NBR      Number               3  Thousands
# 335   2000  2000       NBR      Number               3  Thousands
# 336   2001  2001       NBR      Number               3  Thousands
# 337   2002  2002       NBR      Number               3  Thousands
# ...    ...   ...       ...         ...             ...        ...
# 2422  2014  2014        PC  Percentage               0      Units
# 2423  2015  2015        PC  Percentage               0      Units
# 2424  2016  2016        PC  Percentage               0      Units
# 2425  2017  2017        PC  Percentage               0      Units
# 2426  2018  2018        PC  Percentage               0      Units
#
#       Reference Period Code  Reference Period     Value Flag Codes Flags
# 333                     NaN               NaN  121019.0        NaN   NaN
# 334                     NaN               NaN  123267.0        NaN   NaN
# 335                     NaN               NaN  126535.0        NaN   NaN
# 336                     NaN               NaN  126690.0        NaN   NaN
# 337                     NaN               NaN  126438.0        NaN   NaN
# ...                     ...               ...       ...        ...   ...
# 2422                    NaN               NaN      10.7        NaN   NaN
# 2423                    NaN               NaN      10.6        NaN   NaN
# 2424                    NaN               NaN      10.3        NaN   NaN
# 2425                    NaN               NaN      10.3        NaN   NaN
# 2426                    NaN               NaN      10.1        NaN   NaN
#
# [63 rows x 17 columns]

# %%
tud_df1 = tud_df[tud_df["SERIES"] == "TUD"]

# %%
len(tud_df1["COU"].value_counts())
# Out:
# 36

# %%
tud_df1[tud_df1["SOURCE"] == "ADM"]["Country"].value_counts()
# Out:
# United Kingdom     21
# Belgium            21
# Italy              21
# Germany            21
# Norway             21
# France             21
# Netherlands        21
# Japan              21
# Finland            21
# Denmark            21
# Austria            21
# Czech Republic     21
# Spain              21
# Switzerland        20
# New Zealand        20
# Sweden             20
# Estonia            20
# Korea              20
# Chile              19
# Slovak Republic    19
# Slovenia           19
# Canada             18
# Luxembourg         17
# Ireland            17
# Poland             16
# Lithuania          16
# Hungary            14
# Latvia             14
# Turkey             13
# Iceland            12
# Portugal            9
# Australia           7
# Greece              7
# Mexico              5
# Israel              4
# Name: Country, dtype: int64

# %%
tud_df1[tud_df1["SOURCE"] != "ADM"]["Country"].value_counts()
# Out:
# United Kingdom    21
# Canada            21
# United States     21
# Sweden            21
# Australia         19
# Ireland           18
# Estonia           18
# Mexico            17
# Iceland           16
# Netherlands       16
# Korea             15
# France            12
# Finland           10
# Norway             8
# Luxembourg         5
# Spain              5
# Hungary            3
# New Zealand        3
# Israel             3
# Name: Country, dtype: int64

# %%
tud_df1[tud_df1["Country"] == "United Kingdom"]
# Out:
#       COU         Country SOURCE               Source SERIES  \
# 948   GBR  United Kingdom    SVY          Survey data    TUD
# 949   GBR  United Kingdom    SVY          Survey data    TUD
# 950   GBR  United Kingdom    SVY          Survey data    TUD
# 951   GBR  United Kingdom    SVY          Survey data    TUD
# 952   GBR  United Kingdom    SVY          Survey data    TUD
# 953   GBR  United Kingdom    SVY          Survey data    TUD
# 954   GBR  United Kingdom    SVY          Survey data    TUD
# 955   GBR  United Kingdom    SVY          Survey data    TUD
# 956   GBR  United Kingdom    SVY          Survey data    TUD
# 957   GBR  United Kingdom    SVY          Survey data    TUD
# 958   GBR  United Kingdom    SVY          Survey data    TUD
# 959   GBR  United Kingdom    SVY          Survey data    TUD
# 960   GBR  United Kingdom    SVY          Survey data    TUD
# 961   GBR  United Kingdom    SVY          Survey data    TUD
# 962   GBR  United Kingdom    SVY          Survey data    TUD
# 963   GBR  United Kingdom    SVY          Survey data    TUD
# 964   GBR  United Kingdom    SVY          Survey data    TUD
# 965   GBR  United Kingdom    SVY          Survey data    TUD
# 966   GBR  United Kingdom    SVY          Survey data    TUD
# 967   GBR  United Kingdom    SVY          Survey data    TUD
# 968   GBR  United Kingdom    SVY          Survey data    TUD
# 2005  GBR  United Kingdom    ADM  Administrative data    TUD
# 2006  GBR  United Kingdom    ADM  Administrative data    TUD
# 2007  GBR  United Kingdom    ADM  Administrative data    TUD
# 2008  GBR  United Kingdom    ADM  Administrative data    TUD
# 2009  GBR  United Kingdom    ADM  Administrative data    TUD
# 2010  GBR  United Kingdom    ADM  Administrative data    TUD
# 2011  GBR  United Kingdom    ADM  Administrative data    TUD
# 2012  GBR  United Kingdom    ADM  Administrative data    TUD
# 2013  GBR  United Kingdom    ADM  Administrative data    TUD
# 2014  GBR  United Kingdom    ADM  Administrative data    TUD
# 2015  GBR  United Kingdom    ADM  Administrative data    TUD
# 2016  GBR  United Kingdom    ADM  Administrative data    TUD
# 2017  GBR  United Kingdom    ADM  Administrative data    TUD
# 2018  GBR  United Kingdom    ADM  Administrative data    TUD
# 2019  GBR  United Kingdom    ADM  Administrative data    TUD
# 2020  GBR  United Kingdom    ADM  Administrative data    TUD
# 2021  GBR  United Kingdom    ADM  Administrative data    TUD
# 2022  GBR  United Kingdom    ADM  Administrative data    TUD
# 2023  GBR  United Kingdom    ADM  Administrative data    TUD
# 2024  GBR  United Kingdom    ADM  Administrative data    TUD
# 2025  GBR  United Kingdom    ADM  Administrative data    TUD
#
#                     Series  TIME  Year Unit Code        Unit  PowerCode Code  \
# 948   Trade union  density  1998  1998        PC  Percentage               0
# 949   Trade union  density  1999  1999        PC  Percentage               0
# 950   Trade union  density  2000  2000        PC  Percentage               0
# 951   Trade union  density  2001  2001        PC  Percentage               0
# 952   Trade union  density  2002  2002        PC  Percentage               0
# 953   Trade union  density  2003  2003        PC  Percentage               0
# 954   Trade union  density  2004  2004        PC  Percentage               0
# 955   Trade union  density  2005  2005        PC  Percentage               0
# 956   Trade union  density  2006  2006        PC  Percentage               0
# 957   Trade union  density  2007  2007        PC  Percentage               0
# 958   Trade union  density  2008  2008        PC  Percentage               0
# 959   Trade union  density  2009  2009        PC  Percentage               0
# 960   Trade union  density  2010  2010        PC  Percentage               0
# 961   Trade union  density  2011  2011        PC  Percentage               0
# 962   Trade union  density  2012  2012        PC  Percentage               0
# 963   Trade union  density  2013  2013        PC  Percentage               0
# 964   Trade union  density  2014  2014        PC  Percentage               0
# 965   Trade union  density  2015  2015        PC  Percentage               0
# 966   Trade union  density  2016  2016        PC  Percentage               0
# 967   Trade union  density  2017  2017        PC  Percentage               0
# 968   Trade union  density  2018  2018        PC  Percentage               0
# 2005  Trade union  density  1998  1998        PC  Percentage               0
# 2006  Trade union  density  1999  1999        PC  Percentage               0
# 2007  Trade union  density  2000  2000        PC  Percentage               0
# 2008  Trade union  density  2001  2001        PC  Percentage               0
# 2009  Trade union  density  2002  2002        PC  Percentage               0
# 2010  Trade union  density  2003  2003        PC  Percentage               0
# 2011  Trade union  density  2004  2004        PC  Percentage               0
# 2012  Trade union  density  2005  2005        PC  Percentage               0
# 2013  Trade union  density  2006  2006        PC  Percentage               0
# 2014  Trade union  density  2007  2007        PC  Percentage               0
# 2015  Trade union  density  2008  2008        PC  Percentage               0
# 2016  Trade union  density  2009  2009        PC  Percentage               0
# 2017  Trade union  density  2010  2010        PC  Percentage               0
# 2018  Trade union  density  2011  2011        PC  Percentage               0
# 2019  Trade union  density  2012  2012        PC  Percentage               0
# 2020  Trade union  density  2013  2013        PC  Percentage               0
# 2021  Trade union  density  2014  2014        PC  Percentage               0
# 2022  Trade union  density  2015  2015        PC  Percentage               0
# 2023  Trade union  density  2016  2016        PC  Percentage               0
# 2024  Trade union  density  2017  2017        PC  Percentage               0
# 2025  Trade union  density  2018  2018        PC  Percentage               0
#
#      PowerCode  Reference Period Code  Reference Period  Value Flag Codes  \
# 948      Units                    NaN               NaN   29.9        NaN
# 949      Units                    NaN               NaN   29.7        NaN
# 950      Units                    NaN               NaN   29.8        NaN
# 951      Units                    NaN               NaN   29.3        NaN
# 952      Units                    NaN               NaN   28.8        NaN
# 953      Units                    NaN               NaN   29.3        NaN
# 954      Units                    NaN               NaN   28.8        NaN
# 955      Units                    NaN               NaN   28.6        NaN
# 956      Units                    NaN               NaN   28.3        NaN
# 957      Units                    NaN               NaN   28.0        NaN
# 958      Units                    NaN               NaN   27.5        NaN
# 959      Units                    NaN               NaN   27.4        NaN
# 960      Units                    NaN               NaN   26.6        NaN
# 961      Units                    NaN               NaN   26.0        NaN
# 962      Units                    NaN               NaN   26.1        NaN
# 963      Units                    NaN               NaN   25.6        NaN
# 964      Units                    NaN               NaN   25.0        NaN
# 965      Units                    NaN               NaN   24.7        NaN
# 966      Units                    NaN               NaN   23.6        NaN
# 967      Units                    NaN               NaN   23.3        NaN
# 968      Units                    NaN               NaN   23.4        NaN
# 2005     Units                    NaN               NaN   30.1        NaN
# 2006     Units                    NaN               NaN   30.0        NaN
# 2007     Units                    NaN               NaN   29.7        NaN
# 2008     Units                    NaN               NaN   29.0        NaN
# 2009     Units                    NaN               NaN   28.7        NaN
# 2010     Units                    NaN               NaN   28.5        NaN
# 2011     Units                    NaN               NaN   27.6        NaN
# 2012     Units                    NaN               NaN   27.0        NaN
# 2013     Units                    NaN               NaN   27.2        NaN
# 2014     Units                    NaN               NaN   27.2        NaN
# 2015     Units                    NaN               NaN   27.0        NaN
# 2016     Units                    NaN               NaN   27.0        NaN
# 2017     Units                    NaN               NaN   26.8        NaN
# 2018     Units                    NaN               NaN   26.5        NaN
# 2019     Units                    NaN               NaN   26.1        NaN
# 2020     Units                    NaN               NaN   25.4        NaN
# 2021     Units                    NaN               NaN   25.0        NaN
# 2022     Units                    NaN               NaN   24.2        NaN
# 2023     Units                    NaN               NaN   23.7        NaN
# 2024     Units                    NaN               NaN   23.2        NaN
# 2025     Units                    NaN               NaN   23.4        NaN
#
#      Flags
# 948    NaN
# 949    NaN
# 950    NaN
# 951    NaN
# 952    NaN
# 953    NaN
# 954    NaN
# 955    NaN
# 956    NaN
# 957    NaN
# 958    NaN
# 959    NaN
# 960    NaN
# 961    NaN
# 962    NaN
# 963    NaN
# 964    NaN
# 965    NaN
# 966    NaN
# 967    NaN
# 968    NaN
# 2005   NaN
# 2006   NaN
# 2007   NaN
# 2008   NaN
# 2009   NaN
# 2010   NaN
# 2011   NaN
# 2012   NaN
# 2013   NaN
# 2014   NaN
# 2015   NaN
# 2016   NaN
# 2017   NaN
# 2018   NaN
# 2019   NaN
# 2020   NaN
# 2021   NaN
# 2022   NaN
# 2023   NaN
# 2024   NaN
# 2025   NaN

# %%
years = tud_df1["TIME"].value_counts().index
print(years.min())
print(years.max())
# Out:
# 1998
# 2018

# %%
working_age_df = pd.read_csv("raw_data/working_age_population.csv")
working_age_df
# Out:
#     LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME   Value  Flag Codes
# 0        AUS    WKGPOP     TOT  PC_POP         A  2008  67.499         NaN
# 1        AUS    WKGPOP     TOT  PC_POP         A  2009  67.505         NaN
# 2        AUS    WKGPOP     TOT  PC_POP         A  2010  67.386         NaN
# 3        AUS    WKGPOP     TOT  PC_POP         A  2011  67.226         NaN
# 4        AUS    WKGPOP     TOT  PC_POP         A  2012  66.930         NaN
# ..       ...       ...     ...     ...       ...   ...     ...         ...
# 611      G20    WKGPOP     TOT  PC_POP         A  2014  68.219         NaN
# 612      G20    WKGPOP     TOT  PC_POP         A  2015  68.131         NaN
# 613      G20    WKGPOP     TOT  PC_POP         A  2016  68.013         NaN
# 614      G20    WKGPOP     TOT  PC_POP         A  2017  67.859         NaN
# 615      G20    WKGPOP     TOT  PC_POP         A  2018  67.699         NaN
#
# [616 rows x 8 columns]

# %%
years = working_age_df["TIME"].value_counts().index
print(years.min())
print(years.max())
# Out:
# 2008
# 2018

# %% [markdown]
# ## Gini index
# - < 0.2 represents perfect income equality,
# - 0.2–0.3 relative equality,
# - 0.3–0.4 adequate equality,
# - 0.4–0.5 big income gap,
# - above 0.5 represents severe income gap.
# ## Therefore, the warning level of Gini index is 0.4.

# %% [markdown]
# ## Consumer Price Index (CPI)
# - CPI tracks how much the average Canadian household spends,
# - how that changes over time. At the Bank of Canada, we use it to target inflation.
# - The CPI is a simple and familiar measure of price changes, or inflation.

# %% [markdown]
# ## Read union data from ouputfile.csv

# %%
union_df = pd.read_csv("raw_data/ouputfile.csv")
union_df.head()
# Out:
#    Unnamed: 0  Country               Source                Series  Year  \
# 0          54  Hungary          Survey data  Trade union  density  2004
# 1          55  Hungary          Survey data  Trade union  density  2009
# 2          56  Hungary          Survey data  Trade union  density  2015
# 3          94   Poland  Administrative data  Trade union  density  1999
# 4          95   Poland  Administrative data  Trade union  density  2000
#
#          Unit  Value
# 0  Percentage   16.8
# 1  Percentage   11.9
# 2  Percentage    9.0
# 3  Percentage   29.1
# 4  Percentage   24.7

# %% [markdown]
# ### Check union data on each column

# %%
check_columns(union_df, 5)
# Out:
# ============================================================
# Column: Unnamed: 0
# --------------------
# --- Total Unique Values: 851 ---
# 2260    1
# 1302    1
# 1304    1
# 1305    1
# 1306    1
# Min: 54,  Max: 2511
# ============================================================
# Column: Country
# --------------------
# --- Total Unique Values: 36 ---
# United Kingdom    42
# Sweden            41
# Canada            39
# Estonia           38
# Netherlands       37
# Min: Australia,  Max: United States
# ============================================================
# Column: Source
# --------------------
# --- Total Unique Values: 2 ---
# Administrative data    599
# Survey data            252
# Min: Administrative data,  Max: Survey data
# ============================================================
# Column: Series
# --------------------
# --- Total Unique Values: 1 ---
# Trade union  density    851
# Min: Trade union  density,  Max: Trade union  density
# ============================================================
# Column: Year
# --------------------
# --- Total Unique Values: 21 ---
# 2008    48
# 2013    46
# 2016    45
# 2010    45
# 2012    42
# Min: 1998,  Max: 2018
# ============================================================
# Column: Unit
# --------------------
# --- Total Unique Values: 1 ---
# Percentage    851
# Min: Percentage,  Max: Percentage
# ============================================================
# Column: Value
# --------------------
# --- Total Unique Values: 426 ---
# 10.8    9
# 18.8    7
# 9.0     7
# 17.9    7
# 49.3    6
# Min: 4.3,  Max: 92.6

# %% [markdown]
# ## Gini CPI data from gini_cpi.csv

# %%
gini_cpi_df = pd.read_csv("raw_data/gini_cpi.csv")
gini_cpi_df.head()
# Out:
#    Unnamed: 0    Country MEASURE         Age group  Year Unit Code       Unit  \
# 0           0  Australia    GINI  Total population  2012    0_TO_1  0-1 scale
# 1           1  Australia    GINI  Total population  2014    0_TO_1  0-1 scale
# 2           2  Australia    GINI  Total population  2016    0_TO_1  0-1 scale
# 3           3  Australia    GINI  Total population  2018    0_TO_1  0-1 scale
# 4           6  Australia    GINI  Total population  2010    0_TO_1  0-1 scale
#
#    Value
# 0  0.326
# 1  0.337
# 2  0.330
# 3  0.325
# 4  0.334

# %%
check_columns(gini_cpi_df, 5)
# Out:
# ============================================================
# Column: Unnamed: 0
# --------------------
# --- Total Unique Values: 3906 ---
# 0        1
# 60799    1
# 60803    1
# 62852    1
# 62266    1
# Min: 0,  Max: 66113
# ============================================================
# Column: Country
# --------------------
# --- Total Unique Values: 44 ---
# Czech Republic     135
# Latvia             135
# Lithuania          135
# Slovak Republic    135
# Portugal           135
# Min: Australia,  Max: United States
# ============================================================
# Column: MEASURE
# --------------------
# --- Total Unique Values: 3 ---
# CPI2010    1302
# CPI2015    1302
# GINI       1302
# Min: CPI2010,  Max: GINI
# ============================================================
# Column: Age group
# --------------------
# --- Total Unique Values: 3 ---
# Working age population: 18-65          1302
# Total population                       1302
# Retirement age population: above 65    1302
# Min: Retirement age population: above 65,  Max: Working age population: 18-65
# ============================================================
# Column: Year
# --------------------
# --- Total Unique Values: 11 ---
# 2011    549
# 2009    504
# 2012    486
# 2010    468
# 2013    423
# Min: 2009,  Max: 2019
# ============================================================
# Column: Unit Code
# --------------------
# --- Total Unique Values: 2 ---
# IDX       2604
# 0_TO_1    1302
# Min: 0_TO_1,  Max: IDX
# ============================================================
# Column: Unit
# --------------------
# --- Total Unique Values: 2 ---
# Index        2604
# 0-1 scale    1302
# Min: 0-1 scale,  Max: Index
# ============================================================
# Column: Value
# --------------------
# --- Total Unique Values: 907 ---
# 100.000    240
# 0.298       19
# 0.289       18
# 0.249       16
# 0.262       16
# Min: 0.184,  Max: 162.197349

# %% [markdown]
# ### Merge union_df and gini_cpi-df
# - Get data of common years, 2009 to 2018
#     - union_df includes 21 years, from 1998 to 2018
#     - gini_cpi_df includes 11 years, from 2009 to 2019

# %%
df = pd.merge(union_df, gini_cpi_df, on=["Country", "Year"], suffixes=("_union", "_gini_cpi"))
df.head()
# Out:
#    Unnamed: 0_union  Country       Source                Series  Year  \
# 0                55  Hungary  Survey data  Trade union  density  2009
# 1                55  Hungary  Survey data  Trade union  density  2009
# 2                55  Hungary  Survey data  Trade union  density  2009
# 3                55  Hungary  Survey data  Trade union  density  2009
# 4                55  Hungary  Survey data  Trade union  density  2009
#
#    Unit_union  Value_union  Unnamed: 0_gini_cpi  MEASURE  \
# 0  Percentage         11.9                 7947     GINI
# 1  Percentage         11.9                 7959     GINI
# 2  Percentage         11.9                 7964  CPI2010
# 3  Percentage         11.9                 7976  CPI2010
# 4  Percentage         11.9                29555     GINI
#
#                        Age group Unit Code Unit_gini_cpi  Value_gini_cpi
# 0               Total population    0_TO_1     0-1 scale        0.241000
# 1               Total population    0_TO_1     0-1 scale        0.272000
# 2               Total population       IDX         Index       95.369304
# 3               Total population       IDX         Index       95.369304
# 4  Working age population: 18-65    0_TO_1     0-1 scale        0.245000

# %% [markdown]
# ### Remove unrelated columns

# %%
df_09_18 = df[["Country", "Year", "Value_union", "MEASURE", "Age group", "Value_gini_cpi"]]
df_09_18.head()
# Out:
#    Country  Year  Value_union  MEASURE                      Age group  \
# 0  Hungary  2009         11.9     GINI               Total population
# 1  Hungary  2009         11.9     GINI               Total population
# 2  Hungary  2009         11.9  CPI2010               Total population
# 3  Hungary  2009         11.9  CPI2010               Total population
# 4  Hungary  2009         11.9     GINI  Working age population: 18-65
#
#    Value_gini_cpi
# 0        0.241000
# 1        0.272000
# 2       95.369304
# 3       95.369304
# 4        0.245000

# %% [markdown]
# ### Total population

# %%
total_population = df_09_18[df_09_18["Age group"] == "Total population"]

# %%
gini_tot = total_population[total_population["MEASURE"] == "GINI"]
gini_tot = gini_tot.drop_duplicates(subset=["Country","Year"])

# %%
cpi_tot = total_population[total_population["MEASURE"] != "GINI"]
cpi_tot = cpi_tot.drop_duplicates(subset=["Country","Year"])

# %%
data_total = pd.merge(gini_tot, cpi_tot, on=["Country", "Year"])\
                        .drop(columns=["MEASURE_x", "Age group_x", "Value_union_y", "MEASURE_y", "Age group_y"])
data_total = data_total.rename(columns = {
                                                "Value_union_x": "Union %",
                                                "Value_gini_cpi_x": "Gini",
                                                "Value_gini_cpi_y": "CPI"
                                            })
data_total.head()
# Out:
#    Country  Year  Union %   Gini         CPI
# 0  Hungary  2009     11.9  0.241   95.369304
# 1  Hungary  2015      9.0  0.284  111.384411
# 2   Poland  2009     16.3  0.303   97.484226
# 3   Poland  2010     18.3  0.304  100.000000
# 4   Poland  2011     17.0  0.301  104.239401

# %% [markdown]
# ### Working age population: 18~65

# %%
working_age = df_09_18[df_09_18["Age group"] == "Working age population: 18-65"]

gini_working = working_age[working_age["MEASURE"] == "GINI"]
gini_working = gini_working.drop_duplicates(subset=["Country","Year"])

cpi_working = working_age[working_age["MEASURE"] != "GINI"]
cpi_working = cpi_working.drop_duplicates(subset=["Country","Year"])

data_working = pd.merge(gini_working, cpi_working, on=["Country", "Year"])\
                        .drop(columns=["MEASURE_x", "Age group_x", "Value_union_y", "MEASURE_y", "Age group_y"])
data_working = data_working.rename(columns = {
                                                "Value_union_x": "Union %",
                                                "Value_gini_cpi_x": "Gini",
                                                "Value_gini_cpi_y": "CPI"
                                            })
data_working

data_working.to_csv("Untitled Folder/data_working.csv")

# %%
data_working.plot.scatter(x="Union %", y="Gini")

# %%
west = ['United Kingdom', 'Spain', 'Austria', 'France', 'Germany', 'Ireland', 'Switzerland', 'Italy', 'Luxembourg', 'Greece', 'Israel'
                 'Netherlands', 'Belgium', 'Australia', 'New Zealand', 'Portugal', 'Turkey', 'Canada']
east =  ['Estonia', 'Czech Republic', 'Latvia', 'Lithuania', 'Hungary', 'Slovak Republic', 'Slovenia', 'Poland'] 
scandinavian = ['Norway', 'Finland' ,'Iceland', 'Sweden', 'Denmark']
us = ['United States']
asia = ['Korea', 'Japan']
latin = ['Mexico', 'Chile']

# %%
west_df = pd.DataFrame({"Country": west})
east_df = pd.DataFrame({"Country": east})
scand_df = pd.DataFrame({"Country": scandinavian})
us_df = pd.DataFrame({"Country": us})
asia_df = pd.DataFrame({"Country": asia})
latin_df = pd.DataFrame({"Country": latin})

# %%
# data_working[data_working["Country"] == west_df["Country"]]

west_filter = pd.merge(data_working, west_df, on=["Country"])
east_filter = pd.merge(data_working, east_df, on=["Country"])
scand_filter = pd.merge(data_working, scand_df, on=["Country"])
us_filter = pd.merge(data_working, us_df, on=["Country"])
asia_filter = pd.merge(data_working, asia_df, on=["Country"])
latin_filter = pd.merge(data_working, latin_df, on=["Country"])

df = {
    "west": {"df": west_filter, "x":0, "y":0, "color": "red"},
    "east": {"df": east_filter, "x":0, "y":1, "color": "blue"},
    "scand": {"df":scand_filter, "x":1, "y":0, "color": "green"},
    "us": {"df":us_filter, "x":1, "y":1, "color": "yellow"},
    "asia": {"df":asia_filter, "x":2, "y":0, "color": "pink"},
    "latin": {"df":latin_filter, "x":2, "y":1, "color": "purple"}
}

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))

for region in df:
    x_position=df[region]["x"]
    y_position=df[region]["y"]
    df[region]["df"].plot.scatter(x="Union %", y="Gini", ax=ax[x_position][y_position], grid=True)
    ax[x_position][y_position].set_title(region)
    ax[x_position][y_position].set_ylim(0, 0.55)
    ax[x_position][y_position].set_xlim(0, 100)
    
    x = df[region]["df"]["Union %"]
    y = df[region]["df"]["Gini"]
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    ax[x_position][y_position].plot(x, regress_values, "r-")
    
    ax[x_position][y_position].annotate(region, (70,0.5), fontsize=16, color="darkblue")
    ax[x_position][y_position].annotate(line_eq, (70,0.45), fontsize=16, color="darkblue")
    ax[x_position][y_position].annotate(f"rvalue: {round(rvalue,2)}", (70,0.4), fontsize=16, color="darkblue")

# %%
data_working
data_working["Color"] = ""
data_working["Group"] = ""
data_working.head()
# Out:
#    Country  Year  Union %   Gini         CPI Color Group
# 0  Hungary  2009     11.9  0.245   95.369304
# 1  Hungary  2015      9.0  0.291  111.384411
# 2   Poland  2009     16.3  0.305   97.484226
# 3   Poland  2010     18.3  0.307  100.000000
# 4   Poland  2011     17.0  0.304  104.239401

# %%
for index, row in data_working.iterrows():
    if row["Country"] in west: 
        data_working.loc[index,"Group"] = "West"
        data_working.loc[index,"Color"] = "b"
    if row["Country"] in east: 
        data_working.loc[index,"Group"] = "East" 
        data_working.loc[index,"Color"] = "g"
    if row["Country"] in scandinavian: 
        data_working.loc[index,"Group"] = "Scandinavia"
        data_working.loc[index,"Color"] = "r"
    if row["Country"] in us: 
        data_working.loc[index,"Group"] = "US" 
        data_working.loc[index,"Color"] = "p"
    if row["Country"] in asia: 
        data_working.loc[index,"Group"] = "Asia" 
        data_working.loc[index,"Color"] = "y"
    if row["Country"] in latin: 
        data_working.loc[index,"Group"] = "Latin"
        data_working.loc[index,"Color"] = "t"
data_working.head()
# data_working.plot.scatter(x="Union %", y="Gini", c="Group", colormap="viridis")
# Out:
#    Country  Year  Union %   Gini         CPI Color Group
# 0  Hungary  2009     11.9  0.245   95.369304     g  East
# 1  Hungary  2015      9.0  0.291  111.384411     g  East
# 2   Poland  2009     16.3  0.305   97.484226     g  East
# 3   Poland  2010     18.3  0.307  100.000000     g  East
# 4   Poland  2011     17.0  0.304  104.239401     g  East

# %%
from matplotlib import cm
cmap = cm.get_cmap('Spectral')

# %%
plt.figure(figsize=(15, 10))
i = 0
for region in df:
    x = df[region]["df"]["Union %"]
    y = df[region]["df"]["Gini"]
    plt.scatter(x, y, c=df[region]["color"] )
    plt.annotate(f"{region}: {df[region]['color']}", (80, 0.5 - i*0.02), fontsize=16, color="darkblue"  )
    i += 1

x = data_working["Union %"]
y = data_working["Gini"]
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
regress_values = x * slope + intercept
line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.plot(x, regress_values, "r-")


plt.annotate(line_eq, (60,0.5), fontsize=16, color="darkblue")
plt.annotate(f"rvalue: {round(rvalue,2)}", (60,0.48), fontsize=16, color="darkblue")
# Out:
# Text(60, 0.48, 'rvalue: -0.47')

# %%
# data_working.plot.scatter(x="Union %", y="Gini", c="Group", colormap="viridis")

# %%
by_country = data_working.groupby(["Country"])
plt.figure()
plt.plot()
# Out:
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Country
# Australia          AxesSubplot(0.125,0.125;0.775x0.755)
# Austria            AxesSubplot(0.125,0.125;0.775x0.755)
# Belgium            AxesSubplot(0.125,0.125;0.775x0.755)
# Canada             AxesSubplot(0.125,0.125;0.775x0.755)
# Chile              AxesSubplot(0.125,0.125;0.775x0.755)
# Czech Republic     AxesSubplot(0.125,0.125;0.775x0.755)
# Denmark            AxesSubplot(0.125,0.125;0.775x0.755)
# Estonia            AxesSubplot(0.125,0.125;0.775x0.755)
# Finland            AxesSubplot(0.125,0.125;0.775x0.755)
# France             AxesSubplot(0.125,0.125;0.775x0.755)
# Germany            AxesSubplot(0.125,0.125;0.775x0.755)
# Greece             AxesSubplot(0.125,0.125;0.775x0.755)
# Hungary            AxesSubplot(0.125,0.125;0.775x0.755)
# Iceland            AxesSubplot(0.125,0.125;0.775x0.755)
# Ireland            AxesSubplot(0.125,0.125;0.775x0.755)
# Israel             AxesSubplot(0.125,0.125;0.775x0.755)
# Italy              AxesSubplot(0.125,0.125;0.775x0.755)
# Japan              AxesSubplot(0.125,0.125;0.775x0.755)
# Korea              AxesSubplot(0.125,0.125;0.775x0.755)
# Latvia             AxesSubplot(0.125,0.125;0.775x0.755)
# Lithuania          AxesSubplot(0.125,0.125;0.775x0.755)
# Luxembourg         AxesSubplot(0.125,0.125;0.775x0.755)
# Mexico             AxesSubplot(0.125,0.125;0.775x0.755)
# Netherlands        AxesSubplot(0.125,0.125;0.775x0.755)
# New Zealand        AxesSubplot(0.125,0.125;0.775x0.755)
# Norway             AxesSubplot(0.125,0.125;0.775x0.755)
# Poland             AxesSubplot(0.125,0.125;0.775x0.755)
# Portugal           AxesSubplot(0.125,0.125;0.775x0.755)
# Slovak Republic    AxesSubplot(0.125,0.125;0.775x0.755)
# Slovenia           AxesSubplot(0.125,0.125;0.775x0.755)
# Spain              AxesSubplot(0.125,0.125;0.775x0.755)
# Sweden             AxesSubplot(0.125,0.125;0.775x0.755)
# Switzerland        AxesSubplot(0.125,0.125;0.775x0.755)
# Turkey             AxesSubplot(0.125,0.125;0.775x0.755)
# United Kingdom     AxesSubplot(0.125,0.125;0.775x0.755)
# United States      AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
data_working["Union %"].plot.box()

# %%
data_working[["Gini"]].plot.box()

# %%
data_working[["CPI"]].plot.box()

# %%
data_working.plot.scatter(x="Union %", y="CPI")

# %%
data_working[data_working["Year"] == 2018].plot.scatter(x="Gini", y="CPI")

# %%
x = data_working["Gini"]
y = data_working["CPI"]
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(
                                            ,)
regress_values = x * slope + intercept
line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.figure(figsize=(10,8))
plt.scatter(x, y)
plt.plot(x, regress_values, "r-")
plt.annotate(line_eq, (20,36), fontsize=12, color="darkblue")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-4746c8b830fa> in <module>
#       2                                             data_working["Gini"],
#       3                                             data_working["CPI"])
# ----> 4 regress_values = x * slope + intercept
#       5 line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
#       6 plt.figure(figsize=(10,8))
#
# NameError: name 'x' is not defined

# %% [markdown]
# ### Retirement age population: above 65

# %%
retire = df_09_18[df_09_18["Age group"] == "Retirement age population: above 65"]

gini_retire = retire[retire["MEASURE"] == "GINI"]
gini_retire = gini_retire.drop_duplicates(subset=["Country","Year"])

cpi_retire = retire[retire["MEASURE"] != "GINI"]
cpi_retire = cpi_retire.drop_duplicates(subset=["Country","Year"])

data_retire = pd.merge(gini_retire, cpi_retire, on=["Country", "Year"])\
                        .drop(columns=["MEASURE_x", "Age group_x", "Value_union_y", "MEASURE_y", "Age group_y"])
data_retire = data_retire.rename(columns = {
                                                "Value_union_x": "Union %",
                                                "Value_gini_cpi_x": "Gini",
                                                "Value_gini_cpi_y": "CPI"
                                            })
data_retire.head()
# Out:
#    Country  Year  Union %   Gini         CPI
# 0  Hungary  2009     11.9  0.196   95.369304
# 1  Hungary  2015      9.0  0.233  111.384411
# 2   Poland  2009     16.3  0.262   97.484226
# 3   Poland  2010     18.3  0.261  100.000000
# 4   Poland  2011     17.0  0.255  104.239401

# %% [markdown]
# ### Seperate by gini and cpi to two columns

# %%
gini_df = df_09_18[df_09_18["MEASURE"] == "GINI"]
cpi_df = df_09_18[df_09_18["MEASURE"] != "GINI"]
pd.merge(gini_df, cpi_df, on=["Country", "Year", "Age group"], suffixes=("_gini", "_cpi"))
# Out:
#             Country  Year  Value_union_gini MEASURE_gini  \
# 0           Hungary  2009              11.9         GINI
# 1           Hungary  2009              11.9         GINI
# 2           Hungary  2009              11.9         GINI
# 3           Hungary  2009              11.9         GINI
# 4           Hungary  2009              11.9         GINI
# ...             ...   ...               ...          ...
# 5365  United States  2017              10.3         GINI
# 5366  United States  2017              10.3         GINI
# 5367  United States  2017              10.3         GINI
# 5368  United States  2017              10.3         GINI
# 5369  United States  2017              10.3         GINI
#
#                                 Age group  Value_gini_cpi_gini  \
# 0                        Total population                0.241
# 1                        Total population                0.241
# 2                        Total population                0.241
# 3                        Total population                0.241
# 4                        Total population                0.272
# ...                                   ...                  ...
# 5365                     Total population                0.390
# 5366        Working age population: 18-65                0.383
# 5367        Working age population: 18-65                0.383
# 5368  Retirement age population: above 65                0.411
# 5369  Retirement age population: above 65                0.411
#
#       Value_union_cpi MEASURE_cpi  Value_gini_cpi_cpi
# 0                11.9     CPI2010           95.369304
# 1                11.9     CPI2010           95.369304
# 2                11.9     CPI2015           85.621770
# 3                11.9     CPI2015           85.621770
# 4                11.9     CPI2010           95.369304
# ...               ...         ...                 ...
# 5365             10.3     CPI2015          103.418600
# 5366             10.3     CPI2010          112.411595
# 5367             10.3     CPI2015          103.418600
# 5368             10.3     CPI2010          112.411595
# 5369             10.3     CPI2015          103.418600
#
# [5370 rows x 9 columns]

# %%
gini_df = df[df["MEASURE"] == "GINI"]
gini_df
# Out:
#       Unnamed: 0_union        Country       Source                Series  \
# 0                   55        Hungary  Survey data  Trade union  density
# 1                   55        Hungary  Survey data  Trade union  density
# 4                   55        Hungary  Survey data  Trade union  density
# 5                   55        Hungary  Survey data  Trade union  density
# 8                   55        Hungary  Survey data  Trade union  density
# ...                ...            ...          ...                   ...
# 4007              2424  United States  Survey data  Trade union  density
# 4009              2424  United States  Survey data  Trade union  density
# 4014              2425  United States  Survey data  Trade union  density
# 4016              2425  United States  Survey data  Trade union  density
# 4018              2425  United States  Survey data  Trade union  density
#
#       Year  Unit_union  Value_union  Unnamed: 0_gini_cpi MEASURE  \
# 0     2009  Percentage         11.9                 7947    GINI
# 1     2009  Percentage         11.9                 7959    GINI
# 4     2009  Percentage         11.9                29555    GINI
# 5     2009  Percentage         11.9                29567    GINI
# 8     2009  Percentage         11.9                42679    GINI
# ...    ...         ...          ...                  ...     ...
# 4007  2016  Percentage         10.3                37034    GINI
# 4009  2016  Percentage         10.3                49244    GINI
# 4014  2017  Percentage         10.3                21788    GINI
# 4016  2017  Percentage         10.3                37035    GINI
# 4018  2017  Percentage         10.3                49245    GINI
#
#                                 Age group Unit Code Unit_gini_cpi  \
# 0                        Total population    0_TO_1     0-1 scale
# 1                        Total population    0_TO_1     0-1 scale
# 4           Working age population: 18-65    0_TO_1     0-1 scale
# 5           Working age population: 18-65    0_TO_1     0-1 scale
# 8     Retirement age population: above 65    0_TO_1     0-1 scale
# ...                                   ...       ...           ...
# 4007        Working age population: 18-65    0_TO_1     0-1 scale
# 4009  Retirement age population: above 65    0_TO_1     0-1 scale
# 4014                     Total population    0_TO_1     0-1 scale
# 4016        Working age population: 18-65    0_TO_1     0-1 scale
# 4018  Retirement age population: above 65    0_TO_1     0-1 scale
#
#       Value_gini_cpi
# 0              0.241
# 1              0.272
# 4              0.245
# 5              0.283
# 8              0.196
# ...              ...
# 4007           0.385
# 4009           0.408
# 4014           0.390
# 4016           0.383
# 4018           0.411
#
# [1341 rows x 13 columns]

# %%
gini_df.plot.scatter(x="Value_y", y="Value_x")
plt.xlabel("Trade Union Density")
plt.ylabel("Gini Value")
plt.title("Gini vs. Trade Union Density")
plt.savefig("images/gini_tud.png")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Value_y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-b19591ef3d62> in <module>
# ----> 1 gini_df.plot.scatter(x="Value_y", y="Value_x")
#       2 plt.xlabel("Trade Union Density")
#       3 plt.ylabel("Gini Value")
#       4 plt.title("Gini vs. Trade Union Density")
#       5 plt.savefig("images/gini_tud.png")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwargs)
#    1617             ...                       colormap='viridis')
#    1618         """
# -> 1619         return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#    1620
#    1621     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None, **kwargs):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     898         if kind in self._dataframe_kinds:
#     899             if isinstance(data, ABCDataFrame):
# --> 900                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     901             else:
#     902                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     278         self._compute_plot_data()
#     279         self._setup_subplots()
# --> 280         self._make_plot()
#     281         self._add_table()
#     282         self._make_legend()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1040             label = None
#    1041         scatter = ax.scatter(
# -> 1042             data[x].values,
#    1043             data[y].values,
#    1044             c=c_values,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Value_y'

# %%
cpi_df = df[df["MEASURE"] != "GINI"]
cpi_df

# %%
cpi_df.plot.scatter(x="Value_y", y="Value_x")
plt.xlabel("Trade Union Density")
plt.ylabel("CPI")
plt.title("CPI vs. Trade Union Density")
plt.savefig("images/cpi_tud.png")

# %%
gini_2018_df = gini_df[(gini_df["Year"] == 2018) & (gini_df["Age group"] == "Total population")]
gini_2018_df

# %%
gini_2018_df.plot.bar(x="Country", y="Value_x", figsize=(20,4))

# %%
cpi_2018_df = cpi_df[(cpi_df["Year"] == 2018) & (cpi_df["Age group"] == "Total population")]
cpi_2018_df

# %%
cpi_2018_df.plot.bar(x="Country", y="Value_x", figsize=(20,4))
