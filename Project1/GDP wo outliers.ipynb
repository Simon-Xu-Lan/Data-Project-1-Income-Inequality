# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
#from utility import check_columns
import scipy.stats as st


# Import .csv
file_GDP = 'Resources/GDP_OECD_v2.csv'
GDP_df = pd.read_csv(file_GDP, index_col=1)
#GDP_df.head()

#GDP_df['Country'] = 'Dummy'


#GDP_df = GDP_df.rename(columns={'LOCATION': 'Country', 'TIME': 'Year'}, inplace=True)

GDP_dfv2=GDP_df.replace({'LOCATION': {'AUS':'Australia', 'AUT': 'Austria', 'BEL': 'Belgium', 
                             'CAN': 'Canada', 'CZE': 'Czech Republic', 'DNK': 'Denmark',
                             'FIN': 'Finland', 'FRA': 'France',  'DEU': 'Germany',                           
                             'GRC': 'Greece', 'HUN': 'Hungary',  'ISL': 'Iceland',
                             'IRL': 'Ireland', 'ITA': 'Italy', 'JPN': 'Japan',
                             'KOR': 'Korea','LUX': 'Luxembourg', 'MEX': 'Mexico', 
                             'NLD': 'Netherlands',  'NZL': 'New Zealand', 'NOR': 'Norway',
                             'POL': 'Poland','PRT': 'Portugal','SVK': 'Slovak Republic',
                             'SVN': 'Slovenia','ESP': 'Spain','SWE': 'Sweden', 'GBR': 'United Kingdom',
                             'TUR': 'Turkey',  'USA': 'United States','CHE': 'Sitzerland',
                             'CHL': 'Chile', 'EST': 'Estonia','ISR': 'Israel',
                             'LVA': 'Latvia', 'LTU': 'Lithuania'}
                            })
#GDP_df.head()
GDP_dfv2.head()
# Out:
#             LOCATION SUBJECT  MEASURE FREQUENCY  TIME        Value Flag Codes
# INDICATOR
# GDP        Australia     TOT  USD_CAP         A  2009  41614.09072        NaN
# GDP        Australia     TOT  USD_CAP         A  2010  42787.06596        NaN
# GDP        Australia     TOT  USD_CAP         A  2011  44419.30975        NaN
# GDP        Australia     TOT  USD_CAP         A  2012  43879.18036        NaN
# GDP        Australia     TOT  USD_CAP         A  2013  47761.21406        NaN

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np
from scipy import stats

# %%
GDP_dfv2['LOCATION'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Czech Republic',
#        'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
#        'Iceland', 'Ireland', 'Italy', 'Japan', 'Korea', 'Luxembourg',
#        'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Poland',
#        'Portugal', 'Slovak Republic', 'Spain', 'Sweden', 'Sitzerland',
#        'Turkey', 'United Kingdom', 'United States', 'Chile', 'CHN', 'COL',
#        'Estonia', 'IND', 'IDN', 'Israel', 'RUS', 'Slovenia', 'ZAF',
#        'EU28', 'OECD', 'OECDE', 'Latvia', 'BRA', 'Lithuania', 'SAU',
#        'EA19', 'ARG', 'CRI', 'BGR', 'HRV', 'CYP', 'MLT', 'PER', 'ROU',
#        'MKD', 'ZMB', 'HKG', 'MDG', 'MAR', 'SGP'], dtype=object)

# %%
#GDP_dfv3 = 
GDP_dfv2.rename(columns={'LOCATION': 'Country', 'TIME': 'Year'}, inplace=True)
#GDP_dfv3.head()
GDP_dfv2.head()
# Out:
#              Country SUBJECT  MEASURE FREQUENCY  Year        Value Flag Codes
# INDICATOR
# GDP        Australia     TOT  USD_CAP         A  2009  41614.09072        NaN
# GDP        Australia     TOT  USD_CAP         A  2010  42787.06596        NaN
# GDP        Australia     TOT  USD_CAP         A  2011  44419.30975        NaN
# GDP        Australia     TOT  USD_CAP         A  2012  43879.18036        NaN
# GDP        Australia     TOT  USD_CAP         A  2013  47761.21406        NaN

# %%
# Import .csv
file_Union = 'Resources/Union_Pct.csv'
Union_df = pd.read_csv(file_Union, index_col=0)
Union_df.head()
# Out:
#        Country       Source                Series  Year        Unit  Value
# 969  Australia  Survey data  Trade union  density  1998  Percentage   28.1
# 970  Australia  Survey data  Trade union  density  1999  Percentage   26.0
# 971  Australia  Survey data  Trade union  density  2000  Percentage   24.9
# 972  Australia  Survey data  Trade union  density  2001  Percentage   24.6
# 973  Australia  Survey data  Trade union  density  2002  Percentage   23.2

# %%
Union_df['Country'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Chile',
#        'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Israel',
#        'Italy', 'Japan', 'Korea', 'Latvia', 'Lithuania', 'Luxembourg',
#        'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Poland',
#        'Portugal', 'Slovak Republic', 'Slovenia', 'Spain', 'Sweden',
#        'Switzerland', 'Turkey', 'United Kingdom', 'United States'],
#       dtype=object)

# %%
GDP_data_complete = Union_df.merge(GDP_dfv2, on=["Country", "Year"])
GDP_data_complete
# Out:
#            Country       Source                Series  Year        Unit  \
# 0        Australia  Survey data  Trade union  density  2009  Percentage
# 1        Australia  Survey data  Trade union  density  2010  Percentage
# 2        Australia  Survey data  Trade union  density  2011  Percentage
# 3        Australia  Survey data  Trade union  density  2012  Percentage
# 4        Australia  Survey data  Trade union  density  2013  Percentage
# ..             ...          ...                   ...   ...         ...
# 396  United States  Survey data  Trade union  density  2014  Percentage
# 397  United States  Survey data  Trade union  density  2015  Percentage
# 398  United States  Survey data  Trade union  density  2016  Percentage
# 399  United States  Survey data  Trade union  density  2017  Percentage
# 400  United States  Survey data  Trade union  density  2018  Percentage
#
#      Value_x SUBJECT  MEASURE FREQUENCY      Value_y Flag Codes
# 0       19.6     TOT  USD_CAP         A  41614.09072        NaN
# 1       18.4     TOT  USD_CAP         A  42787.06596        NaN
# 2       18.4     TOT  USD_CAP         A  44419.30975        NaN
# 3       18.2     TOT  USD_CAP         A  43879.18036        NaN
# 4       17.0     TOT  USD_CAP         A  47761.21406        NaN
# ..       ...     ...      ...       ...          ...        ...
# 396     10.7     TOT  USD_CAP         A  55008.01240        NaN
# 397     10.6     TOT  USD_CAP         A  56831.65482        NaN
# 398     10.3     TOT  USD_CAP         A  58000.88803        NaN
# 399     10.3     TOT  USD_CAP         A  60091.56878        NaN
# 400     10.1     TOT  USD_CAP         A  63043.04647        NaN
#
# [401 rows x 11 columns]

# %%
GDP_data_complete.to_csv('consolidated.csv')

# %%
GDP_working_df=GDP_data_complete[['Country', 'Year', 'Value_x', 'Value_y']]

GDP_working_df.head()
# Out:
#      Country  Year  Value_x      Value_y
# 0  Australia  2009     19.6  41614.09072
# 1  Australia  2010     18.4  42787.06596
# 2  Australia  2011     18.4  44419.30975
# 3  Australia  2012     18.2  43879.18036
# 4  Australia  2013     17.0  47761.21406

# %%
GDP_working_df=GDP_data_complete[['Country', 'Year', 'Value_x', 'Value_y']]

GDP_working_df.head()
# Out:
#      Country  Year  Value_x      Value_y
# 0  Australia  2009     19.6  41614.09072
# 1  Australia  2010     18.4  42787.06596
# 2  Australia  2011     18.4  44419.30975
# 3  Australia  2012     18.2  43879.18036
# 4  Australia  2013     17.0  47761.21406

# %%
GDP_working_df.rename(columns={'Value_x': 'Union Pct', 'Value_y': 'GDP'}, inplace=True)
GDP_working_df.head()
# Out:
# C:\Users\berry\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#      Country  Year  Union Pct          GDP
# 0  Australia  2009       19.6  41614.09072
# 1  Australia  2010       18.4  42787.06596
# 2  Australia  2011       18.4  44419.30975
# 3  Australia  2012       18.2  43879.18036
# 4  Australia  2013       17.0  47761.21406

# %%
GDP_working_df.plot.scatter(x='Union Pct', y='GDP')
# Out:
# <AxesSubplot:xlabel='Union Pct', ylabel='GDP'>

# %%
west = ['United Kingdom', 'Spain', 'Austria', 
            'France', 'Germany', 'Ireland', 
            'Switzerland', 'Italy', 'Luxembourg', 
            'Greece', 'Israel','Netherlands', 
            'Belgium', 'Australia', 'New Zealand', 
            'Portugal', 'Turkey', 'Canada']


east =  ['Estonia', 'Czech Republic', 'Latvia', 
             'Lithuania', 'Hungary', 'Slovak Republic', 
             'Slovenia', 'Poland'] 

scandinavian = ['Norway', 'Finland' ,'Iceland', 'Sweden', 'Denmark']

us = ['United States']

asia = ['Korea', 'Japan']

latin = ['Mexico', 'Chile']

# %%
west_df = pd.DataFrame({"Country": west})
east_df = pd.DataFrame({"Country": east})
scand_df = pd.DataFrame({"Country": scandinavian})
us_df = pd.DataFrame({"Country": us})
asia_df = pd.DataFrame({"Country": asia})
latin_df = pd.DataFrame({"Country": latin})

# %%
west_filter = pd.merge(GDP_working_df, west_df, on=["Country"])
east_filter = pd.merge(GDP_working_df, east_df, on=["Country"])
scand_filter = pd.merge(GDP_working_df, scand_df, on=["Country"])
us_filter = pd.merge(GDP_working_df, us_df, on=["Country"])
asia_filter = pd.merge(GDP_working_df, asia_df, on=["Country"])
latin_filter = pd.merge(GDP_working_df, latin_df, on=["Country"])

df = {
    "west": {"df": west_filter, "x":0, "y":0, "color": "red"},
    "east": {"df": east_filter, "x":0, "y":1, "color": "blue"},
    "scand": {"df":scand_filter, "x":1, "y":0, "color": "green"},
    "us": {"df":us_filter, "x":1, "y":1, "color": "yellow"},
    "asia": {"df":asia_filter, "x":2, "y":0, "color": "pink"},
    "latin": {"df":latin_filter, "x":2, "y":1, "color": "purple"}
}

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))

for region in df:
    x_position=df[region]["x"]
    y_position=df[region]["y"]
    df[region]["df"].plot.scatter(x="Union Pct", y="GDP", ax=ax[x_position][y_position], grid=True)
    ax[x_position][y_position].set_title(region)
    ax[x_position][y_position].set_ylim(0, 125000)
    ax[x_position][y_position].set_xlim(0, 100)
    
    x = df[region]["df"]["Union Pct"]
    y = df[region]["df"]["GDP"]
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    ax[x_position][y_position].plot(x, regress_values, "r-")
    
    ax[x_position][y_position].annotate(region, (70,60000), fontsize=16, color="darkblue")
    ax[x_position][y_position].annotate(line_eq, (70,80000), fontsize=16, color="darkblue")
    ax[x_position][y_position].annotate(f"rvalue: {round(rvalue,2)}", (70,100000), fontsize=16, color="darkblue")

# %%
GDP_working_df
GDP_working_df["Color"] = ""
GDP_working_df["Group"] = ""
GDP_working_df.head()
# Out:
# <ipython-input-17-19eeb91b3440>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GDP_working_df["Color"] = ""
# <ipython-input-17-19eeb91b3440>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GDP_working_df["Group"] = ""
#      Country  Year  Union Pct          GDP Color Group
# 0  Australia  2009       19.6  41614.09072
# 1  Australia  2010       18.4  42787.06596
# 2  Australia  2011       18.4  44419.30975
# 3  Australia  2012       18.2  43879.18036
# 4  Australia  2013       17.0  47761.21406

# %%
for index, row in GDP_working_df.iterrows():
    if row["Country"] in west: 
        GDP_working_df.loc[index,"Group"] = "West"
        GDP_working_df.loc[index,"Color"] = "b"
    if row["Country"] in east: 
        GDP_working_df.loc[index,"Group"] = "East" 
        GDP_working_df.loc[index,"Color"] = "g"
    if row["Country"] in scandinavian: 
        GDP_working_df.loc[index,"Group"] = "Scandinavia"
        GDP_working_df.loc[index,"Color"] = "r"
    if row["Country"] in us: 
        GDP_working_df.loc[index,"Group"] = "US" 
        GDP_working_df.loc[index,"Color"] = "p"
    if row["Country"] in asia: 
        GDP_working_df.loc[index,"Group"] = "Asia" 
        GDP_working_df.loc[index,"Color"] = "y"
    if row["Country"] in latin: 
        GDP_working_df.loc[index,"Group"] = "Latin"
        GDP_working_df.loc[index,"Color"] = "t"
GDP_working_df.head()
# Out:
# C:\Users\berry\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#      Country  Year  Union Pct          GDP Color Group
# 0  Australia  2009       19.6  41614.09072     b  West
# 1  Australia  2010       18.4  42787.06596     b  West
# 2  Australia  2011       18.4  44419.30975     b  West
# 3  Australia  2012       18.2  43879.18036     b  West
# 4  Australia  2013       17.0  47761.21406     b  West

# %%
gdp=GDP_working_df["GDP"]
quartiles=gdp.quantile([.25,.5,.75])
lowerq=quartiles[0.25]
upperq=quartiles[.75]
gdpiqr=upperq - lowerq
gdplower_bound=lowerq-(1.5*gdpiqr)
gdpupper_bound=upperq+(1.5*gdpiqr)
print(f"The IQR is: {gdpiqr}")
outliers=GDP_working_df.loc[(GDP_working_df['GDP'] < gdplower_bound) | (GDP_working_df['GDP'] > gdpupper_bound)]
print("STATISTICAL OUTLIERS:")
outliers
# Out:
# The IQR is: 15697.521379999998
# STATISTICAL OUTLIERS:
#         Country  Year  Union Pct           GDP Color        Group
# 171     Ireland  2016       25.6   71793.28575     b         West
# 172     Ireland  2016       23.4   71793.28575     b         West
# 173     Ireland  2017       24.5   78990.82586     b         West
# 174     Ireland  2017       24.3   78990.82586     b         West
# 178     Ireland  2018       24.1   87710.31886     b         West
# 240  Luxembourg  2009       35.9   82249.99851     b         West
# 241  Luxembourg  2010       35.1   85587.01465     b         West
# 242  Luxembourg  2010       40.0   85587.01465     b         West
# 243  Luxembourg  2011       35.1   91814.03661     b         West
# 244  Luxembourg  2011       36.6   91814.03661     b         West
# 245  Luxembourg  2012       35.3   91526.72071     b         West
# 246  Luxembourg  2012       35.2   91526.72071     b         West
# 247  Luxembourg  2013       34.8   95246.11389     b         West
# 248  Luxembourg  2013       34.0   95246.11389     b         West
# 249  Luxembourg  2014       34.1  100933.60450     b         West
# 250  Luxembourg  2014       36.3  100933.60450     b         West
# 251  Luxembourg  2015       33.3  103760.12800     b         West
# 252  Luxembourg  2016       32.3  110260.93440     b         West
# 253  Luxembourg  2017       32.1  112545.97030     b         West
# 254  Luxembourg  2018       31.8  120156.75400     b         West
# 307      Norway  2018       49.2   71909.29958     r  Scandinavia

# %%
from matplotlib import cm
cmap = cm.get_cmap('Spectral')

# %%
ud=GDP_working_df["Union Pct"]
quartiles=ud.quantile([.25,.5,.75])
lowerq=quartiles[0.25]
upperq=quartiles[.75]
udiqr=upperq - lowerq
udlower_bound=lowerq-(1.5*udiqr)
udupper_bound=upperq+(1.5*udiqr)
print(f"The IQR is: {udiqr}")
outliers=GDP_working_df.loc[(GDP_working_df['Union Pct'] < udlower_bound) | (GDP_working_df['Union Pct'] > udupper_bound)]
print("STATISTICAL OUTLIERS:")
outliers
# Out:
# The IQR is: 22.3
# STATISTICAL OUTLIERS:
#      Country  Year  Union Pct          GDP Color        Group
# 94   Finland  2009       71.1  38000.01877     r  Scandinavia
# 96   Finland  2010       70.3  38985.87199     r  Scandinavia
# 98   Finland  2011       69.5  40916.64733     r  Scandinavia
# 100  Finland  2012       69.6  40872.85480     r  Scandinavia
# 148  Iceland  2011       83.4  40938.66455     r  Scandinavia
# 149  Iceland  2011       85.0  40938.66455     r  Scandinavia
# 150  Iceland  2013       87.8  44404.73159     r  Scandinavia
# 151  Iceland  2013       88.9  44404.73159     r  Scandinavia
# 152  Iceland  2015       90.0  49203.29499     r  Scandinavia
# 153  Iceland  2015       91.6  49203.29499     r  Scandinavia
# 154  Iceland  2016       89.8  53486.61577     r  Scandinavia
# 155  Iceland  2016       90.4  53486.61577     r  Scandinavia
# 156  Iceland  2018       91.8  59974.51348     r  Scandinavia
# 157  Iceland  2018       90.7  59974.51348     r  Scandinavia
# 158  Iceland  2009       84.9  41802.99936     r  Scandinavia
# 159  Iceland  2010       85.2  39810.80342     r  Scandinavia
# 160  Iceland  2012       85.3  42006.54335     r  Scandinavia
# 161  Iceland  2014       90.4  45995.00169     r  Scandinavia
# 162  Iceland  2017       91.0  55825.94659     r  Scandinavia
# 346   Sweden  2009       70.8  40309.17759     r  Scandinavia
# 348   Sweden  2010       70.2  42256.28007     r  Scandinavia

# %%
len(GDP_working_df["GDP"])
# Out:
# 401

# %%
GDP_wo_outliers_df=GDP_working_df.drop([171,172,173,174,178,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,307,94,96,98,100,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,346])

# %%
plt.figure(figsize=(15,10))
x=GDP_wo_outliers_df["Union Pct"].values.reshape(-1,1)
y=GDP_wo_outliers_df["GDP"].values.reshape(-1,1)
slope, intercept, r_value, p_value, std_err = stats.linregress(x[:,0], y[:,0])
plt.plot(x,y,"o",color="m")
plt.plot(x,intercept+slope*x,"r")
plt.grid(True)
plt.title("Union Density and GDP")
plt.xlabel("Union Density")
plt.ylabel("GDP")
print(f"The Union Density IQR is: {udiqr}")
print(f"The GDP IQR is: {gdpiqr}")
print(f'Coefficient of Determination: {r_value}')
plt.savefig("gdpwooutliers.png")
# Out:
# The Union Density IQR is: 22.3
# The GDP IQR is: 15697.521379999998
# Coefficient of Determination: 0.4927855196185357
